# %%
import scipy
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Standardization Vs. Log-Trnasformation-- https://stats.stackexchange.com/questions/483187/difference-between-log-transformation-and-standardization

# %% [markdown]
# * Standardization does not change the skew of the distribution. What it does is transforming the values so it has μ=0 and σ2=1. The actual distribution shape remains unchanged.
#
# * Log-transformation, on the other hand, changes the skew of the distribution, and is useful when you deal with values that have right-tailed distribution.

# %%
#Create a normal distribution from 0 to 1000
x = scipy.stats.lognorm.rvs(1, loc=0, scale=1000, size=1000)
plt.hist(x, bins=20)
plt.show()

# %% [markdown]
# You can see that X has skewed distribution (long right tail).
#
# Now we do two transformations as follows:

# %%
Z = (x - x.mean()) / x.std()
L = np.log(x)
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].hist(Z, bins=20)
ax[0].set_title('Standardized Data')
ax[1].hist(L, bins=20)
ax[1].set_title('Log Transformed Data')
plt.show()

# %% [markdown]
# As we can see, standardization of X (which is Z in this example) has similar shape of distribution with X. Log-transformation of X (which is L in this example) is now transformed in a way that eliminates its long right tail.
#
# Note that X in the previous example has lognormal distribution X <- rlnorm(1000), that's why the log-transformed variable looks normally distributed. If X is, say, exponentially distributed, the resulting log-transformed variable may not be normal
