# %%
import pandas as pd
import numpy as np
from datetime import date
import cpi
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
pd.set_option('display.max_columns', 500)
main_df = pd.read_csv(r'/home/shua/Desktop/Housetable/Recommender/price_prediction/Pricing_Model_dev/BATCH_API/data/MLS_Reggie/mls_tagged_with API.csv').drop(['Unnamed: 0'], axis = 1)
# Out:
# /tmp/ipykernel_40555/3480252297.py:9: DtypeWarning: Columns (6,9,83,140,305,306,307,308,317,333,337,338,339,345,346,348,350,351,352,354,355,357,358,359,360,365) have mixed types. Specify dtype option on import or set low_memory=False.
#   main_df = pd.read_csv(r'/home/shua/Desktop/Housetable/Recommender/price_prediction/Pricing_Model_dev/BATCH_API/data/MLS_Reggie/mls_tagged_with API.csv').drop(['Unnamed: 0'], axis = 1)

# %%
main_df
# Out:
#                                            full_address  \
# 0     3930 Scandia Way, Eagle Rock, CA 90065 Sold De...
# 1     3930 Scandia Way, Los Angeles, CA 90065 Sold D...
# 2     3913 York Boulevard, Los Angeles, CA 90065 Sol...
# 3     3913 York Boulevard, Los Angeles, CA 90065 Sol...
# 4     4171 Division Street, Los Angeles, CA 90065 So...
# ...                                                 ...
# 4733  2307 E 120th Street, Los Angeles, CA 90059 Sol...
# 4734  11209 Alvaro Street, Los Angeles, CA 90059 Sol...
# 4735  11209 Alvaro Street, Los Angeles, CA 90059 Sol...
# 4736  11709 Compton Avenue, Los Angeles, CA 90059 So...
# 4737  11709 Compton Avenue, Los Angeles, CA 90059 So...
#
#                                                 address             street  \
# 0     3930 scandia way, eagle rock, ca 90065 sold de...   3930 scandia way
# 1     3930 scandia way, los angeles, ca 90065 sold d...   3930 scandia way
# 2     3913 york boulevard, los angeles, ca 90065 sol...     3913 york blvd
# 3     3913 york boulevard, los angeles, ca 90065 sol...     3913 york blvd
# 4     4171 division street, los angeles, ca 90065 so...   4171 division st
# ...                                                 ...                ...
# 4733  2307 e 120th street, los angeles, ca 90059 sol...    2307 e 120th st
# 4734  11209 alvaro street, los angeles, ca 90059 sol...    11209 alvaro st
# 4735  11209 alvaro street, los angeles, ca 90059 sol...    11209 alvaro st
# 4736  11709 compton avenue, los angeles, ca 90059 so...  11709 compton ave
# 4737  11709 compton avenue, los angeles, ca 90059 so...  11709 compton ave
#
#              city state    zip sold_month sold_day year_sold  \
# 0      eagle rock    ca  90065   december        9      2016
# 1     los angeles    ca  90065   december       10      2021
# 2     los angeles    ca  90065        may       17      2021
# 3     los angeles    ca  90065        may       15      2019
# 4     los angeles    ca  90065   december        4      2020
# ...           ...   ...    ...        ...      ...       ...
# 4733  los angeles    ca  90059   november       18      2016
# 4734  los angeles    ca  90059    decmber       29      2020
# 4735  los angeles    ca  90059      march       12      2021
# 4736  los angeles    ca  90059      march       22      2017
# 4737  los angeles    ca  90059       july       26      2017
#
#                                    _id  \
# 0     f52f35d9104e5aad2ef9bc3928cd2a94
# 1     f52f35d9104e5aad2ef9bc3928cd2a94
# 2     bd0f820c618e7c25440d4c03134d8716
# 3     bd0f820c618e7c25440d4c03134d8716
# 4     219dd470f5ea8ab435e37bffc35f425c
# ...                                ...
# 4733  50fb9465a1b1a386f3401dcd5d4d9f3a
# 4734  49e72bc0d1d76e5f65d5ed62858ac7c8
# 4735  49e72bc0d1d76e5f65d5ed62858ac7c8
# 4736  a2cad53dcbac5ccd85b07032969d22de
# 4737  a2cad53dcbac5ccd85b07032969d22de
#
#                                   homeownerAssociations  \
# 0     [{'type': 'HOA', 'feeAmount': 50, 'feeFrequenc...
# 1     [{'type': 'HOA', 'feeAmount': 50, 'feeFrequenc...
# 2     [{'type': 'PUD', 'feeAmount': 1200, 'feeFreque...
# 3     [{'type': 'PUD', 'feeAmount': 1200, 'feeFreque...
# 4                                                    []
# ...                                                 ...
# 4733  [{'type': 'HOA', 'feeAmount': 300, 'feeFrequen...
# 4734                                                 []
# 4735                                                 []
# 4736  [{'type': 'HOA', 'feeAmount': 700, 'feeFrequen...
# 4737  [{'type': 'HOA', 'feeAmount': 700, 'feeFrequen...
#
#                          address.oldHashes  address.houseNumber  \
# 0     ['69caaeb301bf765901902fe925fb00c6']                 3930
# 1     ['69caaeb301bf765901902fe925fb00c6']                 3930
# 2     ['b43856dd6378b5fe5fbf2be2ea4e4eb0']                 3913
# 3     ['b43856dd6378b5fe5fbf2be2ea4e4eb0']                 3913
# 4     ['25ab81db62ddb996af270d6e8b3685da']                 4171
# ...                                    ...                  ...
# 4733  ['436448683304538d6e005cbe3628536d']                 2307
# 4734  ['bc27faa252240ae45b94258f6cd7ec9d']                11209
# 4735  ['bc27faa252240ae45b94258f6cd7ec9d']                11209
# 4736  ['d13bb7d5e939dd1e49f1975087e1d6e7']                11709
# 4737  ['d13bb7d5e939dd1e49f1975087e1d6e7']                11709
#
#      address.county  address.zipPlus4  \
# 0       Los Angeles              3648
# 1       Los Angeles              3648
# 2       Los Angeles              3718
# 3       Los Angeles              3718
# 4       Los Angeles              4205
# ...             ...               ...
# 4733    Los Angeles              2629
# 4734    Los Angeles              1707
# 4735    Los Angeles              1707
# 4736    Los Angeles              1826
# 4737    Los Angeles              1826
#
#                                      address.localities  \
# 0        ['los angeles', 'northeast los angeles', 'la']
# 1        ['los angeles', 'northeast los angeles', 'la']
# 2        ['los angeles', 'northeast los angeles', 'la']
# 3        ['los angeles', 'northeast los angeles', 'la']
# 4        ['los angeles', 'northeast los angeles', 'la']
# ...                                                 ...
# 4733  ['los angeles', 'south los angeles', 'south ga...
# 4734         ['los angeles', 'south los angeles', 'la']
# 4735         ['los angeles', 'south los angeles', 'la']
# 4736         ['los angeles', 'south los angeles', 'la']
# 4737         ['los angeles', 'south los angeles', 'la']
#
#                           address.hash  address.latitude  address.longitude  \
# 0     69caaeb301bf765901902fe925fb00c6         34.118304        -118.227664
# 1     69caaeb301bf765901902fe925fb00c6         34.118304        -118.227664
# 2     b43856dd6378b5fe5fbf2be2ea4e4eb0         34.125078        -118.232762
# 3     b43856dd6378b5fe5fbf2be2ea4e4eb0         34.125078        -118.232762
# 4     25ab81db62ddb996af270d6e8b3685da         34.116889        -118.221632
# ...                                ...               ...                ...
# 4733  436448683304538d6e005cbe3628536d         33.923615        -118.231406
# 4734  bc27faa252240ae45b94258f6cd7ec9d         33.932780        -118.253429
# 4735  bc27faa252240ae45b94258f6cd7ec9d         33.932780        -118.253429
# 4736  d13bb7d5e939dd1e49f1975087e1d6e7         33.927416        -118.246541
# 4737  d13bb7d5e939dd1e49f1975087e1d6e7         33.927416        -118.246541
#
#       address.normalized  address.countyFipsCode address.formattedStreet  \
# 0                   True                    6037             Scandia Way
# 1                   True                    6037             Scandia Way
# 2                   True                    6037               York Blvd
# 3                   True                    6037               York Blvd
# 4                   True                    6037             Division St
# ...                  ...                     ...                     ...
# 4733                True                    6037              E 120th St
# 4734                True                    6037               Alvaro St
# 4735                True                    6037               Alvaro St
# 4736                True                    6037             Compton Ave
# 4737                True                    6037             Compton Ave
#
#      address.streetNoUnit address.geoStatusCode address.geoStatus  \
# 0        3930 Scandia Way                     B           Rooftop
# 1        3930 Scandia Way                     B           Rooftop
# 2          3913 York Blvd                     B           Rooftop
# 3          3913 York Blvd                     B           Rooftop
# 4        4171 Division St                     B           Rooftop
# ...                   ...                   ...               ...
# 4733      2307 E 120th St                     B           Rooftop
# 4734      11209 Alvaro St                     B           Rooftop
# 4735      11209 Alvaro St                     B           Rooftop
# 4736    11709 Compton Ave                     B           Rooftop
# 4737    11709 Compton Ave                     B           Rooftop
#
#       assessment.assessedImprovementValue  assessment.assessedLandValue  \
# 0                                  141100                        564406
# 1                                  141100                        564406
# 2                                  149432                        597728
# 3                                  149432                        597728
# 4                                  181000                        724000
# ...                                   ...                           ...
# 4733                               127591                        231594
# 4734                                73800                        295200
# 4735                                73800                        295200
# 4736                                53609                        214439
# 4737                                53609                        214439
#
#       assessment.totalAssessedValue  assessment.assessmentYear  \
# 0                            705506                       2021
# 1                            705506                       2021
# 2                            747160                       2021
# 3                            747160                       2021
# 4                            905000                       2021
# ...                             ...                        ...
# 4733                         359185                       2021
# 4734                         369000                       2021
# 4735                         369000                       2021
# 4736                         268048                       2021
# 4737                         268048                       2021
#
#       building.totalBuildingAreaSquareFeet building.totalBuildingAreaCode  \
# 0                                   1208.0                              L
# 1                                   1208.0                              L
# 2                                   1121.0                              L
# 3                                   1121.0                              L
# 4                                   1250.0                              L
# ...                                    ...                            ...
# 4733                                 753.0                              L
# 4734                                 830.0                              L
# 4735                                 830.0                              L
# 4736                                 744.0                              L
# 4737                                 744.0                              L
#
#      building.totalBuildingAreaCodeDescription  building.yearBuilt  \
# 0                                  Living Area              1932.0
# 1                                  Living Area              1932.0
# 2                                  Living Area              1939.0
# 3                                  Living Area              1939.0
# 4                                  Living Area              1947.0
# ...                                        ...                 ...
# 4733                               Living Area              1915.0
# 4734                               Living Area              1940.0
# 4735                               Living Area              1940.0
# 4736                               Living Area              1927.0
# 4737                               Living Area              1927.0
#
#       building.effectiveYearBuilt  building.buildingCount  building.roomCount  \
# 0                          1932.0                     1.0                 5.0
# 1                          1932.0                     1.0                 5.0
# 2                          2005.0                     1.0                 5.0
# 3                          2005.0                     1.0                 5.0
# 4                          1947.0                     1.0                 6.0
# ...                           ...                     ...                 ...
# 4733                       1915.0                     1.0                 NaN
# 4734                       1940.0                     1.0                 NaN
# 4735                       1940.0                     1.0                 NaN
# 4736                       1940.0                     1.0                 4.0
# 4737                       1940.0                     1.0                 4.0
#
#       building.unitCount  building.bedroomCount  \
# 0                      1                    2.0
# 1                      1                    2.0
# 2                      1                    2.0
# 3                      1                    2.0
# 4                      1                    2.0
# ...                  ...                    ...
# 4733                   1                    2.0
# 4734                   1                    2.0
# 4735                   1                    2.0
# 4736                   1                    4.0
# 4737                   1                    4.0
#
#       building.calculatedBathroomCount  building.fullBathroomCount  \
# 0                                  1.0                         1.0
# 1                                  1.0                         1.0
# 2                                  2.0                         2.0
# 3                                  2.0                         2.0
# 4                                  1.0                         1.0
# ...                                ...                         ...
# 4733                               1.0                         1.0
# 4734                               1.0                         1.0
# 4735                               1.0                         1.0
# 4736                               1.0                         1.0
# 4737                               1.0                         1.0
#
#       building.bathroomCount  building.storyCode  building.storyCount  \
# 0                        1.0               100.0                  1.0
# 1                        1.0               100.0                  1.0
# 2                        2.0               100.0                  1.0
# 3                        2.0               100.0                  1.0
# 4                        1.0               100.0                  1.0
# ...                      ...                 ...                  ...
# 4733                     1.0               100.0                  1.0
# 4734                     1.0               100.0                  1.0
# 4735                     1.0               100.0                  1.0
# 4736                     1.0               100.0                  1.0
# 4737                     1.0               100.0                  1.0
#
#      building.storyCountDescription  building.garageParkingSpaceCount  \
# 0                           1 story                               1.0
# 1                           1 story                               1.0
# 2                           1 story                               2.0
# 3                           1 story                               2.0
# 4                           1 story                               1.0
# ...                             ...                               ...
# 4733                        1 story                               NaN
# 4734                        1 story                               NaN
# 4735                        1 story                               NaN
# 4736                        1 story                               NaN
# 4737                        1 story                               NaN
#
#       building.residentialUnitCount                  building.features  \
# 0                               1.0                      ['Fireplace']
# 1                               1.0                      ['Fireplace']
# 2                               1.0  ['Air Conditioning', 'Fireplace']
# 3                               1.0  ['Air Conditioning', 'Fireplace']
# 4                               1.0                                 []
# ...                             ...                                ...
# 4733                            1.0                                 []
# 4734                            1.0                                 []
# 4735                            1.0                                 []
# 4736                            1.0                                 []
# 4737                            1.0                                 []
#
#       building.airConditioningSourceCode building.airConditioningSource  \
# 0                                    NaN                            NaN
# 1                                    NaN                            NaN
# 2                                   13.0                            Yes
# 3                                   13.0                            Yes
# 4                                    NaN                            NaN
# ...                                  ...                            ...
# 4733                                 NaN                            NaN
# 4734                                 NaN                            NaN
# 4735                                 NaN                            NaN
# 4736                                 NaN                            NaN
# 4737                                 NaN                            NaN
#
#       building.buildingConditionCode building.buildingCondition  \
# 0                                NaN                        NaN
# 1                                NaN                        NaN
# 2                                3.0                       Good
# 3                                3.0                       Good
# 4                                NaN                        NaN
# ...                              ...                        ...
# 4733                             NaN                        NaN
# 4734                             NaN                        NaN
# 4735                             NaN                        NaN
# 4736                             6.0                    Average
# 4737                             6.0                    Average
#
#       building.buildingQualityCode building.buildingQuality  \
# 0                              4.0                        B
# 1                              4.0                        B
# 2                              1.0                        A
# 3                              1.0                        A
# 4                              7.0                        C
# ...                            ...                      ...
# 4733                           8.0                       C-
# 4734                           7.0                        C
# 4735                           7.0                        C
# 4736                           7.0                        C
# 4737                           7.0                        C
#
#       building.constructionTypeCode building.constructionType  \
# 0                              17.0                      Wood
# 1                              17.0                      Wood
# 2                              17.0                      Wood
# 3                              17.0                      Wood
# 4                              17.0                      Wood
# ...                             ...                       ...
# 4733                           17.0                      Wood
# 4734                           17.0                      Wood
# 4735                           17.0                      Wood
# 4736                           17.0                      Wood
# 4737                           17.0                      Wood
#
#       building.exteriorWallsCode building.exteriorWalls  \
# 0                           12.0                 Stucco
# 1                           12.0                 Stucco
# 2                           12.0                 Stucco
# 3                           12.0                 Stucco
# 4                           12.0                 Stucco
# ...                          ...                    ...
# 4733                         NaN                    NaN
# 4734                         NaN                    NaN
# 4735                         NaN                    NaN
# 4736                        12.0                 Stucco
# 4737                        12.0                 Stucco
#
#       building.heatSourceCode building.heatSource  building.roofCoverCode  \
# 0                         6.0          Floor/Wall                    18.0
# 1                         6.0          Floor/Wall                    18.0
# 2                         3.0             Central                     3.0
# 3                         3.0             Central                     3.0
# 4                         6.0          Floor/Wall                     3.0
# ...                       ...                 ...                     ...
# 4733                      NaN                 NaN                     NaN
# 4734                      6.0          Floor/Wall                     NaN
# 4735                      6.0          Floor/Wall                     NaN
# 4736                      6.0          Floor/Wall                     3.0
# 4737                      6.0          Floor/Wall                     3.0
#
#        building.roofCover  building.roofTypeCode building.roofType  \
# 0                    Tile                    1.0             Gable
# 1                    Tile                    1.0             Gable
# 2     Composition Shingle                    1.0             Gable
# 3     Composition Shingle                    1.0             Gable
# 4     Composition Shingle                    8.0               Hip
# ...                   ...                    ...               ...
# 4733                  NaN                    NaN               NaN
# 4734                  NaN                    NaN               NaN
# 4735                  NaN                    NaN               NaN
# 4736  Composition Shingle                    NaN               NaN
# 4737  Composition Shingle                    NaN               NaN
#
#       building.styleCode building.style  demographics.age  \
# 0                   12.0        Spanish               NaN
# 1                   12.0        Spanish               NaN
# 2                   15.0   Conventional               NaN
# 3                   15.0   Conventional               NaN
# 4                   15.0   Conventional              36.0
# ...                  ...            ...               ...
# 4733                 NaN            NaN               NaN
# 4734                 NaN            NaN               NaN
# 4735                 NaN            NaN               NaN
# 4736                15.0   Conventional              36.0
# 4737                15.0   Conventional              36.0
#
#       demographics.householdSize  demographics.income  demographics.netWorth  \
# 0                            1.0             149400.0                 2500.0
# 1                            1.0             149400.0                 2500.0
# 2                            1.0              87700.0                 2500.0
# 3                            1.0              87700.0                 2500.0
# 4                            2.0             194000.0               375000.0
# ...                          ...                  ...                    ...
# 4733                         NaN              80700.0                 2500.0
# 4734                         NaN                  NaN                    NaN
# 4735                         NaN                  NaN                    NaN
# 4736                         2.0              53600.0                67500.0
# 4737                         2.0              53600.0                67500.0
#
#       demographics.discretionaryIncome demographics.genderCode  \
# 0                               2500.0                     NaN
# 1                               2500.0                     NaN
# 2                               2500.0                       M
# 3                               2500.0                       M
# 4                              57750.0                       M
# ...                                ...                     ...
# 4733                            2500.0                       M
# 4734                               NaN                     NaN
# 4735                               NaN                     NaN
# 4736                           13750.0                       M
# 4737                           13750.0                       M
#
#      demographics.gender demographics.millionaire  \
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                   Male                      NaN
# 3                   Male                      NaN
# 4                   Male                      NaN
# ...                  ...                      ...
# 4733                Male                      NaN
# 4734                 NaN                      NaN
# 4735                 NaN                      NaN
# 4736                Male                      NaN
# 4737                Male                      NaN
#
#      demographics.religiousAffiliationCode demographics.religiousAffiliation  \
# 0                                      NaN                               NaN
# 1                                      NaN                               NaN
# 2                                        P                        Protestant
# 3                                        P                        Protestant
# 4                                        C                          Catholic
# ...                                    ...                               ...
# 4733                                     C                          Catholic
# 4734                                   NaN                               NaN
# 4735                                   NaN                               NaN
# 4736                                     C                          Catholic
# 4737                                     C                          Catholic
#
#       demographics.individualEducationCode demographics.individualEducation  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                      1.0            Completed High School
# ...                                    ...                              ...
# 4733                                   NaN                              NaN
# 4734                                   NaN                              NaN
# 4735                                   NaN                              NaN
# 4736                                   1.0            Completed High School
# 4737                                   1.0            Completed High School
#
#      demographics.recentlyMoved  demographics.recentlyMovedMonth  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                          True                              6.0
# 3                          True                              6.0
# 4                           NaN                              NaN
# ...                         ...                              ...
# 4733                        NaN                              NaN
# 4734                        NaN                              NaN
# 4735                        NaN                              NaN
# 4736                        NaN                              NaN
# 4737                        NaN                              NaN
#
#       demographics.recentlyMovedYear  general.primaryParcel  \
# 0                                NaN                   True
# 1                                NaN                   True
# 2                             2019.0                   True
# 3                             2019.0                   True
# 4                                NaN                   True
# ...                              ...                    ...
# 4733                             NaN                   True
# 4734                             NaN                   True
# 4735                             NaN                   True
# 4736                             NaN                   True
# 4737                             NaN                   True
#
#       general.parcelCount general.vacant general.mailingAddressVacant  \
# 0                       1          False                        False
# 1                       1          False                        False
# 2                       1          False                        False
# 3                       1          False                        False
# 4                       1          False                        False
# ...                   ...            ...                          ...
# 4733                    1          False                        False
# 4734                    1          False                        False
# 4735                    1          False                        False
# 4736                    1          False                        False
# 4737                    1          False                        False
#
#       general.standardizedLandUseCode general.propertyTypeCategory  \
# 0                                1001                  Residential
# 1                                1001                  Residential
# 2                                1001                  Residential
# 3                                1001                  Residential
# 4                                1001                  Residential
# ...                               ...                          ...
# 4733                             1001                  Residential
# 4734                             1001                  Residential
# 4735                             1001                  Residential
# 4736                             1001                  Residential
# 4737                             1001                  Residential
#
#      general.propertyTypeDetail  general.congressionalDistrict  \
# 0                 Single Family                           34.0
# 1                 Single Family                           34.0
# 2                 Single Family                           34.0
# 3                 Single Family                           34.0
# 4                 Single Family                           34.0
# ...                         ...                            ...
# 4733              Single Family                           44.0
# 4734              Single Family                           44.0
# 4735              Single Family                           44.0
# 4736              Single Family                           44.0
# 4737              Single Family                           44.0
#
#      general.timeZone  general.utcOffset  general.daylightSavingsTime  \
# 0             Pacific                 -8                         True
# 1             Pacific                 -8                         True
# 2             Pacific                 -8                         True
# 3             Pacific                 -8                         True
# 4             Pacific                 -8                         True
# ...               ...                ...                          ...
# 4733          Pacific                 -8                         True
# 4734          Pacific                 -8                         True
# 4735          Pacific                 -8                         True
# 4736          Pacific                 -8                         True
# 4737          Pacific                 -8                         True
#
#      general.carrierRoute  general.censusTract  \
# 0                    C013               186302
# 1                    C013               186302
# 2                    C023               186100
# 3                    C023               186100
# 4                    C053               186202
# ...                   ...                  ...
# 4733                 C023               540600
# 4734                 C053               242600
# 4735                 C053               242600
# 4736                 C022               540700
# 4737                 C022               540700
#
#                    general.schoolDistrict                   ids.addressHash  \
# 0     Los Angeles Unified School District  69caaeb301bf765901902fe925fb00c6
# 1     Los Angeles Unified School District  69caaeb301bf765901902fe925fb00c6
# 2     Los Angeles Unified School District  b43856dd6378b5fe5fbf2be2ea4e4eb0
# 3     Los Angeles Unified School District  b43856dd6378b5fe5fbf2be2ea4e4eb0
# 4     Los Angeles Unified School District  25ab81db62ddb996af270d6e8b3685da
# ...                                   ...                               ...
# 4733      Compton Unified School District  436448683304538d6e005cbe3628536d
# 4734  Los Angeles Unified School District  bc27faa252240ae45b94258f6cd7ec9d
# 4735  Los Angeles Unified School District  bc27faa252240ae45b94258f6cd7ec9d
# 4736      Compton Unified School District  d13bb7d5e939dd1e49f1975087e1d6e7
# 4737      Compton Unified School District  d13bb7d5e939dd1e49f1975087e1d6e7
#
#            ids.apn  ids.quantariumUrn  ids.fipsCode ids.personIds  \
# 0     5472-006-005         12835650.0          6037            []
# 1     5472-006-005         12835650.0          6037            []
# 2     5459-025-032         12828800.0          6037            []
# 3     5459-025-032         12828800.0          6037            []
# 4     5472-009-041         12835799.0          6037            []
# ...            ...                ...           ...           ...
# 4733  6150-022-012         13136708.0          6037            []
# 4734  6070-015-018         13099559.0          6037            []
# 4735  6070-015-018         13099559.0          6037            []
# 4736  6149-009-011         13135858.0          6037            []
# 4737  6149-009-011         13135858.0          6037            []
#
#      involuntaryLien.liens                             legal.legalDescription  \
# 0                       []                           TRACT NO 7454 LOT/SEC 94
# 1                       []                           TRACT NO 7454 LOT/SEC 94
# 2                       []             TRACT NO 6124 LOT/SEC 32 BLK/DIV/TWN 1
# 3                       []             TRACT NO 6124 LOT/SEC 32 BLK/DIV/TWN 1
# 4                       []                           TRACT NO 9270 LOT/SEC 17
# ...                    ...                                                ...
# 4733                    []            SPRINGDALE TRACT W 57 FT OF LOT/SEC 189
# 4734                    []                           TRACT NO 8686 LOT/SEC 23
# 4735                    []                           TRACT NO 8686 LOT/SEC 23
# 4736                    []  TRACT NO 5018 (EX OF ST) LOT/SEC 16 BLK/DIV/TWN 9
# 4737                    []  TRACT NO 5018 (EX OF ST) LOT/SEC 16 BLK/DIV/TWN 9
#
#      legal.lotNumber legal.cityTownshipMunicipality legal.tractNumber  \
# 0                 94          East /la Mt Washingtn              7454
# 1                 94          East /la Mt Washingtn              7454
# 2                 32          East /atwatr Eagle Rk              6124
# 3                 32          East /atwatr Eagle Rk              6124
# 4                 17          East /la Mt Washingtn              9270
# ...              ...                            ...               ...
# 4733             189         South /willowbrook Sfr  SPRINGDALE TRACT
# 4734              23               South /watts Sfr              8686
# 4735              23               South /watts Sfr              8686
# 4736              16         South /willowbrook Sfr              5018
# 4737              16         South /willowbrook Sfr              5018
#
#       lot.lotSizeAcres  lot.lotDepthFeet  lot.lotFrontageFeet  \
# 0                0.168               NaN                  NaN
# 1                0.168               NaN                  NaN
# 2                0.101             800.0                550.0
# 3                0.101             800.0                550.0
# 4                0.117             890.0                580.0
# ...                ...               ...                  ...
# 4733             0.280            2100.0                570.0
# 4734             0.110            1190.0                400.0
# 4735             0.110            1190.0                400.0
# 4736             0.050             870.0                250.0
# 4737             0.050             870.0                250.0
#
#       lot.lotSizeSquareFeet lot.zoningCode  lot.estimatedLotSizeSquareFeet  \
# 0                    7296.0           LAR1                          7295.0
# 1                    7296.0           LAR1                          7295.0
# 2                    4381.0           LAR1                          4380.0
# 3                    4381.0           LAR1                          4380.0
# 4                    5103.0           LAR1                          5103.0
# ...                     ...            ...                             ...
# 4733                12186.0         LCR1YY                         12185.0
# 4734                 4776.0           LAR2                          4775.0
# 4735                 4776.0           LAR2                          4775.0
# 4736                 2175.0          LCR2*                          2174.0
# 4737                 2175.0          LCR2*                          2174.0
#
#      mls.mlsNumber mls.status  mls.price  mls.daysOnMarket  \
# 0          P1-7374       Sold   987500.0              25.0
# 1          P1-7374       Sold   987500.0              25.0
# 2         21711198       Sold   895000.0              14.0
# 3         21711198       Sold   895000.0              14.0
# 4         20647702       Sold   849000.0              41.0
# ...            ...        ...        ...               ...
# 4733    DW21137709       Sold   520000.0               1.0
# 4734    DW21023171       Sold   454900.0              24.0
# 4735    DW21023171       Sold   454900.0              24.0
# 4736    OC17120464       Sold   249900.0              57.0
# 4737    OC17120464       Sold   249900.0              57.0
#
#        mls.originalListingDate mls.initialListingStatus mls.statusSubtype  \
# 0     2021-11-06T00:00:00.000Z                   Active              Sold
# 1     2021-11-06T00:00:00.000Z                   Active              Sold
# 2     2021-04-05T00:00:00.000Z                   Active              Sold
# 3     2021-04-05T00:00:00.000Z                   Active              Sold
# 4     2020-10-24T00:00:00.000Z                   Active              Sold
# ...                        ...                      ...               ...
# 4733  2021-06-25T00:00:00.000Z                   Active              Sold
# 4734  2021-02-05T00:00:00.000Z                   Active              Sold
# 4735  2021-02-05T00:00:00.000Z                   Active              Sold
# 4736  2017-05-30T00:00:00.000Z                   Active              Sold
# 4737  2017-05-30T00:00:00.000Z                   Active              Sold
#
#      mls.rentalIndicator  mls.maxListPrice      mls.maxListPriceDate  \
# 0                   Sold          987500.0  2021-11-07T00:00:00.000Z
# 1                   Sold          987500.0  2021-11-07T00:00:00.000Z
# 2                   Sold          895000.0  2021-05-05T00:00:00.000Z
# 3                   Sold          895000.0  2021-05-05T00:00:00.000Z
# 4                   Sold          849000.0  2020-10-25T00:00:00.000Z
# ...                  ...               ...                       ...
# 4733                Sold          520000.0  2021-06-26T00:00:00.000Z
# 4734                Sold          454900.0  2021-02-06T00:00:00.000Z
# 4735                Sold          454900.0  2021-02-06T00:00:00.000Z
# 4736                Sold          279900.0  2017-06-01T00:00:00.000Z
# 4737                Sold          279900.0  2017-06-01T00:00:00.000Z
#
#       mls.minListPrice      mls.minListPriceDate  mls.soldPrice  \
# 0             987500.0  2021-11-07T00:00:00.000Z      1370000.0
# 1             987500.0  2021-11-07T00:00:00.000Z      1370000.0
# 2             895000.0  2021-05-05T00:00:00.000Z      1030000.0
# 3             895000.0  2021-05-05T00:00:00.000Z      1030000.0
# 4             849000.0  2020-10-25T00:00:00.000Z       905000.0
# ...                ...                       ...            ...
# 4733          520000.0  2021-06-26T00:00:00.000Z       560000.0
# 4734          454900.0  2021-02-06T00:00:00.000Z       475000.0
# 4735          454900.0  2021-02-06T00:00:00.000Z       475000.0
# 4736          249900.0  2017-06-22T00:00:00.000Z       255000.0
# 4737          249900.0  2017-06-22T00:00:00.000Z       255000.0
#
#                   mls.soldDate  mls.bedroomCount  mls.bathroomCount  \
# 0     2021-12-01T00:00:00.000Z               2.0                2.0
# 1     2021-12-01T00:00:00.000Z               2.0                2.0
# 2     2021-04-19T00:00:00.000Z               2.0                2.0
# 3     2021-04-19T00:00:00.000Z               2.0                2.0
# 4     2020-12-04T00:00:00.000Z               2.0                2.0
# ...                        ...               ...                ...
# 4733  2021-06-26T00:00:00.000Z               2.0                1.0
# 4734  2021-03-01T00:00:00.000Z               2.0                1.0
# 4735  2021-03-01T00:00:00.000Z               2.0                1.0
# 4736  2017-07-26T00:00:00.000Z               2.0                1.0
# 4737  2017-07-26T00:00:00.000Z               2.0                1.0
#
#      mls.buildingStyle  mls.totalBuildingAreaSquareFeet  \
# 0              SPANISH                           1208.0
# 1              SPANISH                           1208.0
# 2          TRADITIONAL                           1202.0
# 3          TRADITIONAL                           1202.0
# 4          TRADITIONAL                           1250.0
# ...                ...                              ...
# 4733      CONTEMPORARY                            753.0
# 4734       SEE REMARKS                            830.0
# 4735       SEE REMARKS                            830.0
# 4736               NaN                            744.0
# 4737               NaN                            744.0
#
#       mls.lotSizeSquareFeet  mls.floorCount   mls.propertyType  \
# 0                    7405.0             1.0                SFR
# 1                    7405.0             1.0                SFR
# 2                    4381.0             1.0                SFR
# 3                    4381.0             1.0                SFR
# 4                    5103.0             1.0                SFR
# ...                     ...             ...                ...
# 4733                12197.0             1.0  RESIDENTIAL (NEC)
# 4734                 4776.0             1.0                SFR
# 4735                 4776.0             1.0                SFR
# 4736                 2175.0             1.0                SFR
# 4737                 2175.0             1.0                SFR
#
#                                          mls.appliances mls.coolingTypes  \
# 0     ['ELECTRIC RANGE', 'FREEZER', 'GAS OVEN', 'HEA...      ['CENTRAL']
# 1     ['ELECTRIC RANGE', 'FREEZER', 'GAS OVEN', 'HEA...      ['CENTRAL']
# 2     ['DISHWASHER ', 'DISPOSAL', 'REFRIGERATOR', 'W...      ['CENTRAL']
# 3     ['DISHWASHER ', 'DISPOSAL', 'REFRIGERATOR', 'W...      ['CENTRAL']
# 4                  ['GARBAGE DISPOSER', 'REFRIGERATOR']      ['CENTRAL']
# ...                                                 ...              ...
# 4733                                                NaN              NaN
# 4734                               ['GAS OVEN', 'OVEN']  ['SEE REMARKS']
# 4735                               ['GAS OVEN', 'OVEN']  ['SEE REMARKS']
# 4736                                                NaN  ['WALL WINDOW']
# 4737                                                NaN  ['WALL WINDOW']
#
#      mls.heatingTypes                                   mls.agentOffices  \
# 0          ['HEATED']   [{'officeCorporateName': 'Deasy Penner Podley'}]
# 1          ['HEATED']   [{'officeCorporateName': 'Deasy Penner Podley'}]
# 2         ['CENTRAL']  [{'officeAddress': '2633 Lincoln Blvd # 214 Sa...
# 3         ['CENTRAL']  [{'officeAddress': '2633 Lincoln Blvd # 214 Sa...
# 4         ['CENTRAL']  [{'officeAddress': '680 E Colorado Blvd # 150 ...
# ...               ...                                                ...
# 4733              NaN  [{'officeAddress': '6730 Florence Ave Bell Gar...
# 4734  ['SEE REMARKS']  [{'officeAddress': '10535 Foothill Blvd # 100 ...
# 4735  ['SEE REMARKS']  [{'officeAddress': '10535 Foothill Blvd # 100 ...
# 4736         ['WALL']   [{'officeCorporateName': 'Peter Hanson Broker'}]
# 4737         ['WALL']   [{'officeCorporateName': 'Peter Hanson Broker'}]
#
#                                             mls.schools  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     [{'name': 'TOLAND WAY ELEMENTARY SCHOOL', 'cat...
# ...                                                 ...
# 4733                                                NaN
# 4734  [{'name': 'ONE HUNDRED TWELFTH STREET ELEMENTA...
# 4735  [{'name': 'ONE HUNDRED TWELFTH STREET ELEMENTA...
# 4736                                                NaN
# 4737                                                NaN
#
#                                              mls.agents  \
# 0     [{'name': 'Bonnie Matthews CalDRE:', 'primaryP...
# 1     [{'name': 'Bonnie Matthews CalDRE:', 'primaryP...
# 2                         [{'name': 'Alexis Gallardo'}]
# 3                         [{'name': 'Alexis Gallardo'}]
# 4     [{'email': 'tracy@tracydo.com', 'name': 'Tracy...
# ...                                                 ...
# 4733  [{'email': 'Dora_132003@yahoo.com', 'name': 'D...
# 4734  [{'licenseNumber': '01983735', 'name': 'Jun Ho...
# 4735  [{'licenseNumber': '01983735', 'name': 'Jun Ho...
# 4736  [{'email': 'pete4hreg@gmail.com', 'name': 'Pet...
# 4737  [{'email': 'pete4hreg@gmail.com', 'name': 'Pet...
#
#                                      openLien.mortgages  \
# 0     [{'lenderNameBeneficiary': 'DELAWARE PACIFIC',...
# 1     [{'lenderNameBeneficiary': 'DELAWARE PACIFIC',...
# 2     [{'lenderNameBeneficiary': 'UNITED WHOLESALE M...
# 3     [{'lenderNameBeneficiary': 'UNITED WHOLESALE M...
# 4     [{'lenderNameBeneficiary': 'GUARANTEED RATE IN...
# ...                                                 ...
# 4733  [{'lenderNameBeneficiary': 'VISION ONE MORTGAG...
# 4734  [{'lenderNameBeneficiary': 'AHL FUNDING', 'rec...
# ...
# 4736                            NaN                        NaN
# 4737                            NaN                        NaN
#
#       building.buildingClassCode building.buildingClass  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 4733                         NaN                    NaN
# 4734                         NaN                    NaN
# 4735                         NaN                    NaN
# 4736                         NaN                    NaN
# 4737                         NaN                    NaN
#
#      foreclosure.releaseDate  building.heatingFuelTypeCode  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
# ...                      ...                           ...
# 4733                     NaN                           NaN
# 4734                     NaN                           NaN
# 4735                     NaN                           NaN
# 4736                     NaN                           NaN
# 4737                     NaN                           NaN
#
#      building.heatingFuelType demographics.recentlyDivorced  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
# ...                       ...                           ...
# 4733                      NaN                           NaN
# 4734                      NaN                           NaN
# 4735                      NaN                           NaN
# 4736                      NaN                           NaN
# 4737                      NaN                           NaN
#
#      foreclosure.caseNumber foreclosure.defaultDate  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# ...                     ...                     ...
# 4733                    NaN                     NaN
# 4734                    NaN                     NaN
# 4735                    NaN                     NaN
# 4736                    NaN                     NaN
# 4737                    NaN                     NaN
#
#       building.groundFloorAreaSquareFeet  building.garageSquareFeet  \
# 0                                    NaN                        NaN
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
# 3                                    NaN                        NaN
# 4                                    NaN                        NaN
# ...                                  ...                        ...
# 4733                                 NaN                        NaN
# 4734                                 NaN                        NaN
# 4735                                 NaN                        NaN
# 4736                                 NaN                        NaN
# 4737                                 NaN                        NaN
#
#       building.garageUnfinishedSquareFeet  building.garageFinishedSquareFeet  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
# ...                                   ...                                ...
# 4733                                  NaN                                NaN
# 4734                                  NaN                                NaN
# 4735                                  NaN                                NaN
# 4736                                  NaN                                NaN
# 4737                                  NaN                                NaN
#
#       building.partialBathroomCount building.otherRoomsCode  \
# 0                               NaN                     NaN
# 1                               NaN                     NaN
# 2                               NaN                     NaN
# 3                               NaN                     NaN
# 4                               NaN                     NaN
# ...                             ...                     ...
# 4733                            NaN                     NaN
# 4734                            NaN                     NaN
# 4735                            NaN                     NaN
# 4736                            NaN                     NaN
# 4737                            NaN                     NaN
#
#      building.otherRooms  building.porchCode building.porch  legal.district  \
# 0                    NaN                 NaN            NaN             NaN
# 1                    NaN                 NaN            NaN             NaN
# 2                    NaN                 NaN            NaN             NaN
# 3                    NaN                 NaN            NaN             NaN
# 4                    NaN                 NaN            NaN             NaN
# ...                  ...                 ...            ...             ...
# 4733                 NaN                 NaN            NaN             NaN
# 4734                 NaN                 NaN            NaN             NaN
# 4735                 NaN                 NaN            NaN             NaN
# 4736                 NaN                 NaN            NaN             NaN
# 4737                 NaN                 NaN            NaN             NaN
#
#      lot.topographyCode lot.topography lot.siteInfluenceCode  ids.oldApn  \
# 0                   NaN            NaN                   NaN         NaN
# 1                   NaN            NaN                   NaN         NaN
# 2                   NaN            NaN                   NaN         NaN
# 3                   NaN            NaN                   NaN         NaN
# 4                   NaN            NaN                   NaN         NaN
# ...                 ...            ...                   ...         ...
# 4733                NaN            NaN                   NaN         NaN
# 4734                NaN            NaN                   NaN         NaN
# 4735                NaN            NaN                   NaN         NaN
# 4736                NaN            NaN                   NaN         NaN
# 4737                NaN            NaN                   NaN         NaN
#
#      ids.oldApnCode ids.oldApnCodeDescription  legal.assessorsMapReference  \
# 0               NaN                       NaN                          NaN
# 1               NaN                       NaN                          NaN
# 2               NaN                       NaN                          NaN
# 3               NaN                       NaN                          NaN
# 4               NaN                       NaN                          NaN
# ...             ...                       ...                          ...
# 4733            NaN                       NaN                          NaN
# 4734            NaN                       NaN                          NaN
# 4735            NaN                       NaN                          NaN
# 4736            NaN                       NaN                          NaN
# 4737            NaN                       NaN                          NaN
#
#      lot.siteInfluence tax.schoolTaxDistrictCodes foreclosure.dueDate  \
# 0                  NaN                        NaN                 NaN
# 1                  NaN                        NaN                 NaN
# 2                  NaN                        NaN                 NaN
# 3                  NaN                        NaN                 NaN
# 4                  NaN                        NaN                 NaN
# ...                ...                        ...                 ...
# 4733               NaN                        NaN                 NaN
# 4734               NaN                        NaN                 NaN
# 4735               NaN                        NaN                 NaN
# 4736               NaN                        NaN                 NaN
# 4737               NaN                        NaN                 NaN
#
#      price_sold_tagged     date_sold_tagged  zip_tagged  bedrooms_tagged  \
# 0             758000.0  2016-12-09 00:00:00     90065.0              2.0
# 1            1370000.0  2021-12-10 00:00:00     90065.0              2.0
# 2            1030000.0  2021-05-17 00:00:00     90065.0              2.0
# 3             725000.0  2019-05-15 00:00:00     90065.0              2.0
# 4             905000.0  2020-12-04 00:00:00     90065.0              2.0
# ...                ...                  ...         ...              ...
# 4733          335000.0  2016-11-18 00:00:00     90059.0              2.0
# 4734          369000.0  2020-12-29 00:00:00     90059.0              2.0
# 4735          475000.0  2021-03-12 00:00:00     90059.0              2.0
# 4736          200000.0  2017-03-22 00:00:00     90059.0              2.0
# 4737          255000.0  2017-07-26 00:00:00     90059.0              2.0
#
#       bathrooms_tagged living_area_tagged  lot_size_square_ft._tagged  \
# 0                  1.0             1206.0                      7296.0
# 1                  2.0             1206.0                      7296.0
# 2                  2.0             1202.0                      4381.0
# 3                  2.0             1202.0                      4381.0
# 4                  2.0             1250.0                      5103.0
# ...                ...                ...                         ...
# 4733               1.0              753.0                     12186.0
# 4734               1.0              830.0                      4776.0
# 4735               1.0              830.0                      4776.0
# 4736               1.0              744.0                      2174.0
# 4737               1.0              744.0                      2175.0
#
#       year_built_tagged sub_type_tagged  Kitchen_level_tagged  \
# 0                1932.0               S                   4.0
# 1                1932.0               S                   NaN
# 2                1939.0               S                   4.0
# 3                1939.0               S                   4.0
# 4                1947.0               S                   4.0
# ...                 ...             ...                   ...
# 4733             1915.0               S                   4.0
# 4734             1940.0               S                   NaN
# 4735             1940.0               S                   5.0
# 4736             1927.0               S                   4.0
# 4737             1927.0               S                   4.0
#
#       Kitchen_level_std_tagged  Bathroom_max_tagged  Bathroom_min_tagged  \
# 0                          0.0                  5.0                  2.0
# 1                          NaN                  NaN                  NaN
# 2                          0.0                  5.0                  2.0
# 3                          1.0                  4.0                  2.0
# 4                          0.0                  5.0                  2.0
# ...                        ...                  ...                  ...
# 4733                       0.0                  4.0                  2.0
# 4734                       NaN                  NaN                  NaN
# 4735                       0.0                  5.0                  4.0
# 4736                       0.0                  5.0                  2.0
# 4737                       0.0                  4.0                  1.0
#
#       Bathroom_std_tagged  Bathroom_mean_tagged  Floor_max_tagged  \
# 0                     1.0                   3.0               5.0
# 1                     NaN                   NaN               NaN
# 2                     1.0                   4.0               5.0
# 3                     1.0                   3.0               5.0
# 4                     1.0                   4.0               5.0
# ...                   ...                   ...               ...
# 4733                  1.0                   3.0               5.0
# 4734                  NaN                   NaN               NaN
# 4735                  1.0                   4.0               5.0
# 4736                  1.0                   3.0               3.0
# 4737                  1.0                   3.0               3.0
#
#       Floor_min_tagged  Floor_std_tagged  Floor_mean_tagged  Walls_max_tagged  \
# 0                  2.0               1.0                3.0               5.0
# 1                  NaN               NaN                NaN               NaN
# 2                  2.0               1.0                4.0               5.0
# 3                  2.0               1.0                3.0               5.0
# 4                  2.0               1.0                4.0               5.0
# ...                ...               ...                ...               ...
# 4733               3.0               1.0                4.0               3.0
# 4734               NaN               NaN                NaN               NaN
# 4735               3.0               1.0                4.0               5.0
# 4736               2.0               1.0                2.0               3.0
# 4737               2.0               1.0                3.0               5.0
#
#       Walls_min_tagged  Walls_std_tagged  Walls_mean_tagged  Outview_tagged  \
# 0                  2.0               1.0                3.0             2.0
# 1                  NaN               NaN                NaN             NaN
# 2                  2.0               1.0                5.0             2.0
# 3                  2.0               1.0                4.0             2.0
# 4                  2.0               1.0                4.0             2.0
# ...                ...               ...                ...             ...
# 4733               2.0               1.0                3.0             2.0
# 4734               NaN               NaN                NaN             3.0
# 4735               3.0               1.0                4.0             2.0
# 4736               2.0               1.0                3.0             2.0
# 4737               2.0               1.0                4.0             2.0
#
#       Outview_std_tagged  s_tagged
# 0                    1.0       NaN
# 1                    NaN       NaN
# 2                    1.0       NaN
# 3                    1.0       NaN
# 4                    1.0       NaN
# ...                  ...       ...
# 4733                 1.0       NaN
# 4734                 1.0       NaN
# 4735                 1.0       NaN
# 4736                 0.0       NaN
# 4737                 0.0       NaN
#
# [4738 rows x 385 columns]

# %%
df_dropped_na = main_df.dropna(subset = ['price_sold_tagged', 'full_address', 'year_sold', 'sold_month', 'sold_day', 'address', 'address.houseNumber', 'street', 'city',
        'state', 'zip', 'Bathroom_max_tagged',
 'Bathroom_min_tagged',
 'Bathroom_std_tagged',
 'Bathroom_mean_tagged',
 'Floor_max_tagged',
 'Floor_min_tagged',
 'Floor_std_tagged',
 'Floor_mean_tagged',
 'Walls_max_tagged',
 'Walls_min_tagged',
 'Walls_std_tagged',
 'Walls_mean_tagged',
 'Outview_tagged',
 'Outview_std_tagged'], axis = 0)
df_dropped_na.shape
# Out:
# (4632, 385)

# %%
from re import sub
from decimal import Decimal
def convert_money(x):
    try:
        return float(x)
    except:
        return Decimal(sub(r'[^\d.]', '', x))
df_dropped_na.price_sold_tagged = df_dropped_na.price_sold_tagged.apply(convert_money)
# Out:
# /tmp/ipykernel_40555/3447556188.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dropped_na.price_sold_tagged = df_dropped_na.price_sold_tagged.apply(convert_money)

# %%
dub_addresses = df_dropped_na[df_dropped_na[['street']].duplicated(['street'])]['street']
dub_df = df_dropped_na.loc[df_dropped_na['street'].isin(dub_addresses)]
dub_df.shape
# Out:
# (4325, 385)

# %%
dub_addresses
# Out:
# 3           3913 york blvd
# 5         4171 division st
# 7          4234 palmero dr
# 10      4237 caledonia way
# 12         4613 jessica dr
#                ...
# 4726       1814 e 109th st
# 4729       2217 e 117th st
# 4731    2013 n corlett ave
# 4733       2307 e 120th st
# 4737     11709 compton ave
# Name: street, Length: 2203, dtype: object

# %%
dub_df.groupby(['street'])[['Bathroom_max_tagged',
 'Bathroom_min_tagged',
 'Bathroom_std_tagged',
 'Bathroom_mean_tagged',
 'Floor_max_tagged',
 'Floor_min_tagged',
 'Floor_std_tagged',
 'Floor_mean_tagged',
 'Walls_max_tagged',
 'Walls_min_tagged',
 'Walls_std_tagged',
 'Walls_mean_tagged',
 'Outview_tagged',
 'Outview_std_tagged']].std()
columns = ['full_address', 'address', 'sale_between', 'Bathroom_max_tagged',
 'Bathroom_min_tagged',
 'Bathroom_std_tagged',
 'Bathroom_mean_tagged',
 'Floor_max_tagged',
 'Floor_min_tagged',
 'Floor_std_tagged',
 'Floor_mean_tagged',
 'Walls_max_tagged',
 'Walls_min_tagged',
 'Walls_std_tagged',
 'Walls_mean_tagged',
 'Outview_tagged',
 'Outview_std_tagged']

aggregation_columns = ['Bathroom_max_tagged',
 'Bathroom_min_tagged',
 'Bathroom_std_tagged',
 'Bathroom_mean_tagged',
 'Floor_max_tagged',
 'Floor_min_tagged',
 'Floor_std_tagged',
 'Floor_mean_tagged',
 'Walls_max_tagged',
 'Walls_min_tagged',
 'Walls_std_tagged',
 'Walls_mean_tagged',
 'Outview_tagged',
 'Outview_std_tagged']
 
difference_df = pd.DataFrame(columns = columns)

# %%
list_of_data = []
count =0
for house in dub_df['street'].unique():
    house_df = dub_df[dub_df['street'] == house].sort_values(by = ['year_sold', 'sold_month'], ascending = [False, False]).reset_index(drop = True)
    #order the sales by their sale date
    if house_df.shape[0] >2:
        count+=1
    for i, sale_a in house_df.iterrows():
        # print(i)
        # print(sale_a['year_sold'])
        # sale_a = house_df.iloc[i]
        sale_a = house_df.iloc[i]
        try:

            sale_b = house_df.iloc[i+1]
    #         # print(i)
    #         # print(sale_a['street'])
    #         for j, sale_b in house_df.iterrows():
    #             if sale_a > sale_b (don't want the model to predict against itself. Or do we?)
    #             #     continue
            data_point = dict()
            data_point['full_address'] = sale_a['full_address']
            data_point['street'] = house
            data_point['sale_year'] = sale_a['year_sold']
            data_point['prev_sale_year'] = sale_b['year_sold']
            # data_point['time_between_sales'] = int(sale_a['year_sold']) - int(sale_b['year_sold']) #Need to fix in pre-processing

            # print(data_point['sale_between'])
            data_point['sale_price'] = sale_a['price_sold_tagged']
            data_point['prev_sale_price'] = sale_b['price_sold_tagged']
            data_point['price_difference'] = int(float(sale_a['price_sold_tagged'])) - int(float(sale_b['price_sold_tagged']))
            # print(data_point['price_difference'])
            # for col in aggregation_columns:
            #     data_point[col] = int(sale_a[col]) - int(sale_b[col])
            list_of_data.append(data_point)
        except:
            data_point = dict()
            data_point['full_address'] = sale_a['full_address']
            data_point['street'] = house
            data_point['sale_year'] = sale_a['year_sold']
            data_point['prev_sale_year'] = None
            # data_point['time_between_sales'] = int(sale_a['year_sold']) - int(sale_b['year_sold']) #Need to fix in pre-processing

            # print(data_point['sale_between'])
            data_point['sale_price'] = sale_a['price_sold_tagged']
            data_point['prev_sale_price'] = None
            data_point['price_difference'] = None
            # print(data_point['price_difference'])
            # for col in aggregation_columns:
            #     data_point[col] = None
            list_of_data.append(data_point)

print(count)    
difference_df = pd.DataFrame.from_records(list_of_data)
# Out:
# 76

# %%
difference_df
# Out:
#                                            full_address              street  \
# 0     3913 York Boulevard, Los Angeles, CA 90065 Sol...      3913 york blvd
# 1     3913 York Boulevard, Los Angeles, CA 90065 Sol...      3913 york blvd
# 2     4171 Division Street, Los Angeles, CA 90065 So...    4171 division st
# 3     4171 Division Street, Los Angeles, CA 90065 So...    4171 division st
# 4     4234 Palmero Drive, Los Angeles, CA 90065 Sold...     4234 palmero dr
# ...                                                 ...                 ...
# 4320  2013 N Corlett Avenue, Los Angeles, CA 90059 S...  2013 n corlett ave
# 4321  2307 E 120th St, Los Angeles, CA 90059 Sold Au...     2307 e 120th st
# 4322  2307 E 120th Street, Los Angeles, CA 90059 Sol...     2307 e 120th st
# 4323  11709 Compton Avenue, Los Angeles, CA 90059 So...   11709 compton ave
# 4324  11709 Compton Avenue, Los Angeles, CA 90059 So...   11709 compton ave
#
#      sale_year prev_sale_year sale_price  prev_sale_price  price_difference
# 0         2021           2019  1030000.0         725000.0          305000.0
# 1         2019           None   725000.0              NaN               NaN
# 2         2020           2015   905000.0         680000.0          225000.0
# 3         2015           None   680000.0              NaN               NaN
# 4         2020           2017  1260000.0         844000.0          416000.0
# ...        ...            ...        ...              ...               ...
# 4320      2016           None   200000.0              NaN               NaN
# 4321      2021           2016   560000.0         335000.0          225000.0
# 4322      2016           None   335000.0              NaN               NaN
# 4323      2017           2017   200000.0         255000.0          -55000.0
# 4324      2017           None   255000.0              NaN               NaN
#
# [4325 rows x 7 columns]

# %%
difference_df = difference_df.merge(dub_df, how = 'left', on = 'full_address', suffixes= ('', '_b'))

# %%
difference_df.columns
# Out:
# Index(['full_address', 'street', 'sale_year', 'prev_sale_year', 'sale_price',
#        'prev_sale_price', 'price_difference', 'address', 'street_b', 'city',
#        ...
#        'Floor_min_tagged', 'Floor_std_tagged', 'Floor_mean_tagged',
#        'Walls_max_tagged', 'Walls_min_tagged', 'Walls_std_tagged',
#        'Walls_mean_tagged', 'Outview_tagged', 'Outview_std_tagged',
#        's_tagged'],
#       dtype='object', length=391)

# %%
difference_df.to_csv('/home/shua/Desktop/msc-ml-datamining/Machine_Learning/project/difference_df.csv')
