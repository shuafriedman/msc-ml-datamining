# %% [markdown]
# # Los Angeles Greater Area Sales Price Prediction
#
# ### *A Project on behalf of Housetable Ltd*

# %% [markdown]
# ![losangeles.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Introduction

# %% [markdown]
# Housetable is a young startup in Israel, working in the Fintech sector of the young startup scene. Housetable lets American homeowners know what their home will be worth after renovations, its expected costs and timeline, as well as a curated list of improvements that are most likely to increase its value, powered by AI.
#
# An important aspect to this process is the current value of the home, pre-renovation. To do this, they gathered a small dataset of houses and their sale data. Every house has at least 2 entries for different sales at different times. Each sales information was gathered along with the images the homeowner took of the property at listing time. The images were run by Housetables in-house computer vision aglorithms to understand the quality and condition of the interior of the home, and these features were appended to the metadata for its corresponding row.
#
# **The task is to try and create an algorithm to understand the current valuation of homes in the Los Angeles area**, a large and diverse enough area to assume that if the model can learn well enough in Los Angeles, its performance could be consistent in other areas as well.
#
# #### Table of Contents:
# 1. EDA and Cleaning
#     * Feature Selection
#     * Understanding and Cleaning the Target Value
#     * Simple Imputations and Feature Cleaning
#     * Skew and Coorelations
# 2. Feature Engineering
#     * Fill values by aggregation
#     * Create Age and Overall Quality Features
#     * One Hot and Ordinal Encoding
#     * Outlier Removal
# 3. Final Data Prep
#     * Drop Unuseable Columns
#     * Min Max Scaling
#     * KNN Imputer
# 4. Modeling
#     * Without Previous Sales
#     * With Previous Sales (XGBoost)
# 5. Making Use of the Historical Data
#     * Add Conditions of the Previous Sale to Current Sale
#     * Retry the Models

# %%
import pandas as pd
import numpy as np
from datetime import date
import matplotlib.pyplot as plt
# !pip install cpi
# !pip install xgboost
#Turn off settingwithcopy warning
pd.options.mode.chained_assignment = None  # default='warn'
pd.options.display.float_format = '{:.6f}'.format
# Out:
# Requirement already satisfied: cpi in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (1.0.13)
# Requirement already satisfied: pandas in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (from cpi) (1.5.1)
# Requirement already satisfied: python-dateutil in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (from cpi) (2.8.2)
# Requirement already satisfied: requests in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (from cpi) (2.28.1)
# Requirement already satisfied: click in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (from cpi) (8.1.3)
# Requirement already satisfied: pytz>=2020.1 in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (from pandas->cpi) (2022.6)
# Requirement already satisfied: numpy>=1.21.0 in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (from pandas->cpi) (1.23.4)
# Requirement already satisfied: six>=1.5 in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (from python-dateutil->cpi) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (from requests->cpi) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (from requests->cpi) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (from requests->cpi) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (from requests->cpi) (1.26.11)
# Requirement already satisfied: xgboost in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (1.7.0)
# Requirement already satisfied: numpy in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (from xgboost) (1.23.4)
# Requirement already satisfied: scipy in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (from xgboost) (1.9.3)

# %%
main_df = pd.read_csv(r'/home/shua/Desktop/msc-ml-datamining/Machine_Learning/project/final_draft/data/difference_df.csv').drop(['Unnamed: 0'], axis = 1)
# Out:
# /tmp/ipykernel_11145/870541258.py:1: DtypeWarning: Columns (3,4,12,15,146,245,246,250,260,276,288,289,290,291,294,295,296,297,298,300,301,302,303,304,305,309,311,312,313,314,319,320,321,322,323,324,325,326,327,331,332,333,335,336,337,339,342,344,345,351,352,354,356,357,358,360,361,363,364) have mixed types. Specify dtype option on import or set low_memory=False.
#   main_df = pd.read_csv(r'/home/shua/Desktop/msc-ml-datamining/Machine_Learning/project/final_draft/data/difference_df.csv').drop(['Unnamed: 0'], axis = 1)

# %% [markdown]
# ## 1)Exploratory Data Analysis

# %%
main_df.head()
# Out:
#                                         full_address            street  \
# 0  3913 York Boulevard, Los Angeles, CA 90065 Sol...    3913 york blvd
# 1  3913 York Boulevard, Los Angeles, CA 90065 Sol...    3913 york blvd
# 2  4171 Division Street, Los Angeles, CA 90065 So...  4171 division st
# 3  4171 Division Street, Los Angeles, CA 90065 So...  4171 division st
# 4  4234 Palmero Drive, Los Angeles, CA 90065 Sold...   4234 palmero dr
#
#   sale_year prev_sale_year     sale_price  prev_sale_price  price_difference  \
# 0      2021    2019.000000 1030000.000000    725000.000000     305000.000000
# 1      2019            NaN  725000.000000              NaN               NaN
# 2      2020    2015.000000  905000.000000    680000.000000     225000.000000
# 3      2015            NaN  680000.000000              NaN               NaN
# 4      2020    2017.000000 1260000.000000    844000.000000     416000.000000
#
#                                              address          street_b  \
# 0  3913 york boulevard, los angeles, ca 90065 sol...    3913 york blvd
# 1  3913 york boulevard, los angeles, ca 90065 sol...    3913 york blvd
# 2  4171 division street, los angeles, ca 90065 so...  4171 division st
# 3  4171 division street, los angeles, ca 90065 so...  4171 division st
# 4  4234 palmero drive, los angeles, ca 90065 sold...   4234 palmero dr
#
#           city  ... Floor_min_tagged Floor_std_tagged Floor_mean_tagged  \
# 0  los angeles  ...         2.000000         1.000000          4.000000
# 1  los angeles  ...         2.000000         1.000000          3.000000
# 2  los angeles  ...         2.000000         1.000000          4.000000
# 3  los angeles  ...         2.000000         1.000000          4.000000
# 4  los angeles  ...         2.000000         1.000000          3.000000
#
#   Walls_max_tagged Walls_min_tagged Walls_std_tagged Walls_mean_tagged  \
# 0         5.000000         2.000000         1.000000          5.000000
# 1         5.000000         2.000000         1.000000          4.000000
# 2         5.000000         2.000000         1.000000          4.000000
# 3         5.000000         2.000000         1.000000          3.000000
# 4         5.000000         2.000000         1.000000          4.000000
#
#   Outview_tagged  Outview_std_tagged s_tagged
# 0       2.000000            1.000000      NaN
# 1       2.000000            1.000000      NaN
# 2       2.000000            1.000000      NaN
# 3       2.000000            0.000000      NaN
# 4       2.000000            1.000000      NaN
#
# [5 rows x 391 columns]

# %%
main_df.shape
# Out:
# (4339, 391)

# %% [markdown]
# The feature set is rather large-- 391 columns. Let's take a look and see how many of these are actually useable

# %% [markdown]
# ### a)Basic Feature Selection

# %%
#filter the dataframe to only include columns with at least 50% fill rates
main_df.loc[:, main_df.isnull().mean() < .5].shape
# Out:
# (4339, 245)

# %% [markdown]
# With a threshold of 50% fill rates, we managed to remove about 35% of the columns. Lets see what columns we have left:

# %%
filtered_df = main_df.loc[:, main_df.isnull().mean() < .5]
filtered_df.iloc[:, :90].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4339 entries, 0 to 4338
# Data columns (total 90 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   full_address                               4339 non-null   object
#  1   street                                     4339 non-null   object
#  2   sale_year                                  4339 non-null   object
#  3   prev_sale_year                             2212 non-null   object
#  4   sale_price                                 4339 non-null   float64
#  5   prev_sale_price                            2212 non-null   float64
#  6   price_difference                           2212 non-null   float64
#  7   address                                    4339 non-null   object
#  8   street_b                                   4339 non-null   object
#  9   city                                       4339 non-null   object
#  10  state                                      4339 non-null   object
#  11  zip                                        4339 non-null   object
#  12  sold_month                                 4339 non-null   object
#  13  sold_day                                   4339 non-null   object
#  14  year_sold                                  4339 non-null   object
#  15  _id                                        4339 non-null   object
#  16  homeownerAssociations                      4339 non-null   object
#  17  address.oldHashes                          4339 non-null   object
#  18  address.houseNumber                        4339 non-null   int64
#  19  address.county                             4339 non-null   object
#  20  address.zipPlus4                           4339 non-null   int64
#  21  address.localities                         4339 non-null   object
#  22  address.hash                               4339 non-null   object
#  23  address.latitude                           4339 non-null   float64
#  24  address.longitude                          4339 non-null   float64
#  25  address.normalized                         4339 non-null   bool
#  26  address.countyFipsCode                     4339 non-null   int64
#  27  address.formattedStreet                    4339 non-null   object
#  28  address.streetNoUnit                       4339 non-null   object
#  29  address.geoStatusCode                      4339 non-null   object
#  30  address.geoStatus                          4339 non-null   object
#  31  assessment.assessedImprovementValue        4339 non-null   int64
#  32  assessment.assessedLandValue               4339 non-null   int64
#  33  assessment.totalAssessedValue              4339 non-null   int64
#  34  assessment.assessmentYear                  4339 non-null   int64
#  35  building.totalBuildingAreaSquareFeet       4335 non-null   float64
#  36  building.totalBuildingAreaCode             4329 non-null   object
#  37  building.totalBuildingAreaCodeDescription  4329 non-null   object
#  38  building.yearBuilt                         4329 non-null   float64
#  39  building.effectiveYearBuilt                4335 non-null   float64
#  40  building.buildingCount                     4333 non-null   float64
#  41  building.roomCount                         2585 non-null   float64
#  42  building.unitCount                         4339 non-null   int64
#  43  building.bedroomCount                      4335 non-null   float64
#  44  building.calculatedBathroomCount           4337 non-null   float64
#  45  building.fullBathroomCount                 4337 non-null   float64
#  46  building.bathroomCount                     4337 non-null   float64
#  47  building.storyCode                         3173 non-null   float64
#  48  building.storyCount                        3173 non-null   float64
#  49  building.storyCountDescription             3173 non-null   object
#  50  building.garageParkingSpaceCount           2495 non-null   float64
#  51  building.residentialUnitCount              4291 non-null   float64
#  52  building.features                          4339 non-null   object
#  53  building.buildingQualityCode               4283 non-null   float64
#  54  building.buildingQuality                   4283 non-null   object
#  55  building.constructionTypeCode              4327 non-null   float64
#  56  building.constructionType                  4327 non-null   object
#  57  building.exteriorWallsCode                 2202 non-null   float64
#  58  building.exteriorWalls                     2202 non-null   object
#  59  building.heatSourceCode                    4125 non-null   float64
#  60  building.heatSource                        4125 non-null   object
#  61  building.roofCoverCode                     2495 non-null   float64
#  62  building.roofCover                         2495 non-null   object
#  63  building.roofTypeCode                      2181 non-null   float64
#  64  building.roofType                          2181 non-null   object
#  65  building.styleCode                         3176 non-null   float64
#  66  building.style                             3176 non-null   object
#  67  demographics.householdSize                 2341 non-null   float64
#  68  demographics.income                        2507 non-null   float64
#  69  demographics.netWorth                      2509 non-null   float64
#  70  demographics.discretionaryIncome           2509 non-null   float64
#  71  demographics.genderCode                    2177 non-null   object
#  72  demographics.religiousAffiliationCode      2177 non-null   object
#  73  demographics.religiousAffiliation          2177 non-null   object
#  74  general.primaryParcel                      4339 non-null   bool
#  75  general.parcelCount                        4339 non-null   int64
#  76  general.vacant                             4339 non-null   bool
#  77  general.mailingAddressVacant               4283 non-null   object
#  78  general.standardizedLandUseCode            4339 non-null   int64
#  79  general.propertyTypeCategory               4339 non-null   object
#  80  general.propertyTypeDetail                 4339 non-null   object
#  81  general.congressionalDistrict              4339 non-null   float64
#  82  general.timeZone                           4339 non-null   object
#  83  general.utcOffset                          4339 non-null   int64
#  84  general.daylightSavingsTime                4339 non-null   bool
#  85  general.carrierRoute                       4339 non-null   object
#  86  general.censusTract                        4339 non-null   int64
#  87  general.schoolDistrict                     4331 non-null   object
#  88  ids.addressHash                            4339 non-null   object
#  89  ids.apn                                    4339 non-null   object
# dtypes: bool(4), float64(30), int64(12), object(44)
# memory usage: 2.9+ MB

# %%
filtered_df.iloc[:, 90:180].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4339 entries, 0 to 4338
# Data columns (total 90 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   ids.quantariumUrn                         4327 non-null   float64
#  1   ids.fipsCode                              4339 non-null   int64
#  2   ids.personIds                             4339 non-null   object
#  3   involuntaryLien.liens                     4339 non-null   object
#  4   legal.legalDescription                    4339 non-null   object
#  5   legal.lotNumber                           4054 non-null   object
#  6   legal.cityTownshipMunicipality            4339 non-null   object
#  7   legal.tractNumber                         4319 non-null   object
#  8   lot.lotSizeAcres                          4333 non-null   float64
#  9   lot.lotDepthFeet                          2886 non-null   float64
#  10  lot.lotFrontageFeet                       2884 non-null   float64
#  11  lot.lotSizeSquareFeet                     4333 non-null   float64
#  12  lot.zoningCode                            4324 non-null   object
#  13  lot.estimatedLotSizeSquareFeet            4333 non-null   float64
#  14  mls.mlsNumber                             4134 non-null   object
#  15  mls.status                                4140 non-null   object
#  16  mls.price                                 4140 non-null   float64
#  17  mls.daysOnMarket                          4122 non-null   float64
#  18  mls.originalListingDate                   4155 non-null   object
#  19  mls.initialListingStatus                  4140 non-null   object
#  20  mls.statusSubtype                         4140 non-null   object
#  21  mls.rentalIndicator                       4140 non-null   object
#  22  mls.maxListPrice                          3863 non-null   float64
#  23  mls.maxListPriceDate                      3863 non-null   object
#  24  mls.minListPrice                          3843 non-null   float64
#  25  mls.minListPriceDate                      3863 non-null   object
#  26  mls.soldPrice                             3192 non-null   float64
#  27  mls.soldDate                              3617 non-null   object
#  28  mls.bedroomCount                          4267 non-null   float64
#  29  mls.bathroomCount                         4267 non-null   float64
#  30  mls.buildingStyle                         2673 non-null   object
#  31  mls.totalBuildingAreaSquareFeet           4120 non-null   float64
#  32  mls.lotSizeSquareFeet                     3929 non-null   float64
#  33  mls.floorCount                            3620 non-null   float64
#  34  mls.propertyType                          4189 non-null   object
#  35  mls.appliances                            2664 non-null   object
#  36  mls.coolingTypes                          2779 non-null   object
#  37  mls.heatingTypes                          3607 non-null   object
#  38  mls.agentOffices                          4126 non-null   object
#  39  mls.agents                                4101 non-null   object
#  40  openLien.mortgages                        4004 non-null   object
#  41  owner.fullName                            4339 non-null   object
#  42  owner.mailingAddress.houseNumber          4337 non-null   object
#  43  owner.mailingAddress.street               4339 non-null   object
#  44  owner.mailingAddress.city                 4339 non-null   object
#  45  owner.mailingAddress.county               4285 non-null   object
#  46  owner.mailingAddress.state                4339 non-null   object
#  47  owner.mailingAddress.zip                  4339 non-null   int64
#  48  owner.mailingAddress.formattedStreet      4339 non-null   object
#  49  owner.mailingAddress.streetNoUnit         4339 non-null   object
#  50  owner.mailingAddress.hash                 4339 non-null   object
#  51  owner.names                               4339 non-null   object
#  52  owner.ownerOccupied                       4339 non-null   bool
#  53  owner.ownerStatusType                     4339 non-null   object
#  54  owner.lengthOfResidenceMonths             4330 non-null   float64
#  55  owner.ownershipStartDate                  4330 non-null   object
#  56  quickLists.absenteeOwner                  4339 non-null   bool
#  57  quickLists.absenteeOwnerInState           4339 non-null   bool
#  58  quickLists.absenteeOwnerOutOfState        4339 non-null   bool
#  59  quickLists.activeListing                  4339 non-null   bool
#  60  quickLists.activeAuction                  4339 non-null   bool
#  61  quickLists.bankruptcy                     4339 non-null   bool
#  62  quickLists.cashBuyer                      4339 non-null   bool
#  63  quickLists.corporateOwned                 4339 non-null   bool
#  64  quickLists.divorce                        4339 non-null   bool
#  65  quickLists.expiredListing                 4339 non-null   bool
#  66  quickLists.freeAndClear                   4339 non-null   bool
#  67  quickLists.highEquity                     4339 non-null   bool
#  68  quickLists.inherited                      4339 non-null   bool
#  69  quickLists.liens                          4339 non-null   bool
#  70  quickLists.listedBelowMarketPrice         4339 non-null   bool
#  71  quickLists.lowEquity                      4339 non-null   bool
#  72  quickLists.mailingAddressVacant           4339 non-null   bool
#  73  quickLists.noticeOfDefault                4339 non-null   bool
#  74  quickLists.onMarket                       4339 non-null   bool
#  75  quickLists.outOfStateOwner                4339 non-null   bool
#  76  quickLists.ownerOccupied                  4339 non-null   bool
#  77  quickLists.pendingListing                 4339 non-null   bool
#  78  quickLists.preforeclosure                 4339 non-null   bool
#  79  quickLists.recentlySold                   4339 non-null   bool
#  80  quickLists.samePropertyAndMailingAddress  4339 non-null   bool
#  81  quickLists.taxDefault                     4339 non-null   bool
#  82  quickLists.tiredLandlord                  4339 non-null   bool
#  83  quickLists.unknownEquity                  4339 non-null   bool
#  84  quickLists.vacant                         4339 non-null   bool
#  85  quickLists.hasHoaFees                     4339 non-null   bool
#  86  sale.lastTransfer.saleBuyers              4339 non-null   object
#  87  sale.lastTransfer.saleSellers             4339 non-null   object
#  88  sale.lastSale.documentNumber              4330 non-null   float64
#  89  sale.lastSale.documentType                4330 non-null   object
# dtypes: bool(31), float64(18), int64(2), object(39)
# memory usage: 2.1+ MB

# %%
filtered_df.iloc[:, 180:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4339 entries, 0 to 4338
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   sale.lastSale.price                      4304 non-null   float64
#  1   sale.lastSale.priceCodeDescription       3954 non-null   object
#  2   sale.lastSale.priceCode                  4192 non-null   float64
#  3   sale.lastSale.recordingDate              4330 non-null   object
#  4   sale.lastSale.saleDate                   4330 non-null   object
#  5   sale.lastSale.saleBuyers                 4339 non-null   object
#  6   sale.lastSale.saleSellers                4339 non-null   object
#  7   sale.lastSale.mortgages                  4330 non-null   object
#  8   sale.priorTransfer.saleBuyers            4339 non-null   object
#  9   sale.priorTransfer.saleSellers           4339 non-null   object
#  10  sale.priorSale.documentNumber            4306 non-null   float64
#  11  sale.priorSale.documentType              4304 non-null   object
#  12  sale.priorSale.price                     4292 non-null   float64
#  13  sale.priorSale.priceCodeDescription      3963 non-null   object
#  14  sale.priorSale.priceCode                 4203 non-null   float64
#  15  sale.priorSale.recordingDate             4306 non-null   object
#  16  sale.priorSale.saleDate                  4304 non-null   object
#  17  sale.priorSale.saleBuyers                4339 non-null   object
#  18  sale.priorSale.saleSellers               4339 non-null   object
#  19  sale.priorSale.mortgages                 4304 non-null   object
#  20  tax.taxAmount                            4339 non-null   float64
#  21  tax.taxYear                              4339 non-null   int64
#  22  tax.taxRateCodeArea                      4339 non-null   object
#  23  valuation.estimatedValue                 4327 non-null   float64
#  24  valuation.priceRangeMin                  4327 non-null   float64
#  25  valuation.priceRangeMax                  4327 non-null   float64
#  26  valuation.standardDeviation              4327 non-null   float64
#  27  valuation.confidenceScore                4327 non-null   float64
#  28  valuation.asOfDate                       4327 non-null   object
#  29  valuation.equityCurrentEstimatedBalance  4327 non-null   float64
#  30  valuation.equityPercent                  4325 non-null   float64
#  31  meta.importEvents                        4339 non-null   object
#  32  meta.requestId                           4339 non-null   object
#  33  building.livingAreaSquareFeet            2233 non-null   float64
#  34  openLien.totalOpenLienBalance            3190 non-null   float64
#  35  owner.ownershipRightsCode                3515 non-null   object
#  36  owner.ownershipRights                    3515 non-null   object
#  37  openLien.totalOpenLienCount              2314 non-null   float64
#  38  valuation.ltvCurrentEstimatedCombined    2304 non-null   float64
#  39  valuation.ltv                            2304 non-null   float64
#  40  price_sold_tagged                        4339 non-null   float64
#  41  date_sold_tagged                         4339 non-null   object
#  42  zip_tagged                               4339 non-null   float64
#  43  bedrooms_tagged                          4339 non-null   float64
#  44  bathrooms_tagged                         4339 non-null   float64
#  45  living_area_tagged                       4336 non-null   float64
#  46  lot_size_square_ft._tagged               4235 non-null   float64
#  47  year_built_tagged                        4336 non-null   float64
#  48  sub_type_tagged                          4339 non-null   object
#  49  Kitchen_level_tagged                     4111 non-null   float64
#  50  Kitchen_level_std_tagged                 4111 non-null   float64
#  51  Bathroom_max_tagged                      4339 non-null   float64
#  52  Bathroom_min_tagged                      4339 non-null   float64
#  53  Bathroom_std_tagged                      4339 non-null   float64
#  54  Bathroom_mean_tagged                     4339 non-null   float64
#  55  Floor_max_tagged                         4339 non-null   float64
#  56  Floor_min_tagged                         4339 non-null   float64
#  57  Floor_std_tagged                         4339 non-null   float64
#  58  Floor_mean_tagged                        4339 non-null   float64
#  59  Walls_max_tagged                         4339 non-null   float64
#  60  Walls_min_tagged                         4339 non-null   float64
#  61  Walls_std_tagged                         4339 non-null   float64
#  62  Walls_mean_tagged                        4339 non-null   float64
#  63  Outview_tagged                           4339 non-null   float64
#  64  Outview_std_tagged                       4339 non-null   float64
# dtypes: float64(41), int64(1), object(23)
# memory usage: 2.2+ MB

# %% [markdown]
# #### Domain knowledge tells us that many of these features are un-useable/not helpful. This would include the general (with the exception of propertyType.detail), valuation (data leak), quicklists, address, owner, and demographic categories. So we can remove these:

# %%
# remove columns if column starts with any of general, valuation, quicklists, address, owner, and demographic, ids, and categories
filtered_df = filtered_df.loc[:, ~filtered_df.columns.str.lower().str.startswith('general')]
filtered_df = filtered_df.loc[:, ~filtered_df.columns.str.lower().str.startswith('valuation')]
filtered_df = filtered_df.loc[:, ~filtered_df.columns.str.lower().str.startswith('quicklists')]
filtered_df = filtered_df.loc[:, ~filtered_df.columns.str.lower().str.startswith('address')]
filtered_df = filtered_df.loc[:, ~filtered_df.columns.str.lower().str.startswith('owner')]
filtered_df = filtered_df.loc[:, ~filtered_df.columns.str.lower().str.startswith('demographic')]
filtered_df = filtered_df.loc[:, ~filtered_df.columns.str.lower().str.startswith('ids')]
filtered_df = filtered_df.loc[:, ~filtered_df.columns.str.lower().str.startswith('categories')]
filtered_df.shape
# Out:
# (4339, 147)

# %%
#Search through the filtered_df and print a dataframe of just the object columns
object_df = filtered_df.select_dtypes(include=['object'])
object_df.head()
# Out:
#                                         full_address            street  \
# 0  3913 York Boulevard, Los Angeles, CA 90065 Sol...    3913 york blvd
# 1  3913 York Boulevard, Los Angeles, CA 90065 Sol...    3913 york blvd
# 2  4171 Division Street, Los Angeles, CA 90065 So...  4171 division st
# 3  4171 Division Street, Los Angeles, CA 90065 So...  4171 division st
# 4  4234 Palmero Drive, Los Angeles, CA 90065 Sold...   4234 palmero dr
#
#   sale_year prev_sale_year          street_b         city state    zip  \
# 0      2021    2019.000000    3913 york blvd  los angeles    ca  90065
# 1      2019            NaN    3913 york blvd  los angeles    ca  90065
# 2      2020    2015.000000  4171 division st  los angeles    ca  90065
# 3      2015            NaN  4171 division st  los angeles    ca  90065
# 4      2020    2017.000000   4234 palmero dr  los angeles    ca  90065
#
#   sold_month sold_day  ... sale.priorSale.recordingDate  \
# 0        may       17  ...     2019-05-15T00:00:00.000Z
# 1        may       15  ...     2019-05-15T00:00:00.000Z
# 2   december        4  ...     2015-07-22T00:00:00.000Z
# 3       july       22  ...     2015-07-22T00:00:00.000Z
# 4  september       24  ...     2017-03-17T00:00:00.000Z
#
#     sale.priorSale.saleDate  \
# 0  2019-05-09T00:00:00.000Z
# 1  2019-05-09T00:00:00.000Z
# 2  2015-06-19T00:00:00.000Z
# 3  2015-06-19T00:00:00.000Z
# 4  2017-02-09T00:00:00.000Z
#
#                            sale.priorSale.saleBuyers  \
# 0                          ['Spencer Scott William']
# 1                          ['Spencer Scott William']
# 2       ['Vergara Ryan Trajan', 'Vergara Tracy Liu']
# 3       ['Vergara Ryan Trajan', 'Vergara Tracy Liu']
# 4  ['Hoffman Matthew Justin', 'Shelley Noelle Mar...
#
#           sale.priorSale.saleSellers  \
# 0           ['West Adams Group Llc']
# 1           ['West Adams Group Llc']
# 2           ['Berman Shane Michael']
# 3           ['Berman Shane Michael']
# 4  ['Kim Sang Jean', 'Choi David T']
#
#                             sale.priorSale.mortgages tax.taxRateCodeArea  \
# 0  [{'documentNumber': '2019.443302', 'pageNumber...              00-013
# 1  [{'documentNumber': '2019.443302', 'pageNumber...              00-013
# 2  [{'documentNumber': '2015.887850', 'pageNumber...              00-004
# 3  [{'documentNumber': '2015.887850', 'pageNumber...              00-004
# 4  [{'documentNumber': '2017.304648', 'pageNumber...              00-004
#
#   meta.importEvents meta.requestId     date_sold_tagged sub_type_tagged
# 0                []     r2H7QRoLHH  2021-05-17 00:00:00               S
# 1                []     r2H7QRoLHH  2019-05-15 00:00:00               S
# 2                []     GR0zGKANLk  2020-12-04 00:00:00               S
# 3                []     GR0zGKANLk  2015-07-22 00:00:00               S
# 4                []     IjNuIQ38sN  2020-09-24 00:00:00               S
#
# [5 rows x 70 columns]

# %% [markdown]
# As we can see, not all of the features in our dataset are numerical, and will require a decent amount of pre-processing (and thereby feature selection, as not all seem to be able to go through any helpful transoformations).
#
# Two features we can see are actually holding dictionaries: building.features, and homeownerAssociations. Both of these we can sparse later, and get valuable features from.
#
# the general.propertyTypeDetail seems to be ordinal, and can apply an Ordinal Encoder to.
#
# 'building.styleCode', 'building.roofCover','building.exteriorWalls', 'building.heatSource', 'building.constructionType' are all columns which we can apply one hot encoding to.

# %%
# Search through the filtered dataframe and print a dataframe of the numeric columns
numeric_df = filtered_df.select_dtypes(include=['float64', 'int64'])
numeric_df.head(30)
# Out:
#        sale_price  prev_sale_price  price_difference  \
# 0  1030000.000000    725000.000000     305000.000000
# 1   725000.000000              NaN               NaN
# 2   905000.000000    680000.000000     225000.000000
# 3   680000.000000              NaN               NaN
# 4  1260000.000000    844000.000000     416000.000000
# 5   844000.000000              NaN               NaN
# 6  1317000.000000    865000.000000     452000.000000
# 7   865000.000000              NaN               NaN
# 8  1205000.000000    540000.000000     665000.000000
# 9   540000.000000              NaN               NaN
# 10  415000.000000    420000.000000      -5000.000000
# 11  420000.000000              NaN               NaN
# 12  579000.000000    535000.000000      44000.000000
# 13  535000.000000              NaN               NaN
# 14  523000.000000    290000.000000     233000.000000
# 15  290000.000000              NaN               NaN
# 16  442050.000000    493000.000000     -50950.000000
# 17  493000.000000              NaN               NaN
# 18  588000.000000    510000.000000      78000.000000
# 19  510000.000000              NaN               NaN
# 20  470145.000000    495000.000000     -24855.000000
# 21  495000.000000              NaN               NaN
# 22  484000.000000    420000.000000      64000.000000
# 23  420000.000000              NaN               NaN
# 24  535000.000000    500000.000000      35000.000000
# 25  500000.000000              NaN               NaN
# 26  725000.000000    525000.000000     200000.000000
# 27  525000.000000              NaN               NaN
# 28  454000.000000    330000.000000     124000.000000
# 29  330000.000000              NaN               NaN
#
#     assessment.assessedImprovementValue  assessment.assessedLandValue  \
# 0                                149432                        597728
# 1                                149432                        597728
# 2                                181000                        724000
# 3                                181000                        724000
# 4                                302600                        957400
# 5                                302600                        957400
# 6                                267745                        606216
# 7                                267745                        606216
# 8                                321660                        589710
# 9                                321660                        589710
# 10                               169740                        254610
# 11                               169740                        254610
# 12                               140900                        438100
# 13                               140900                        438100
# 14                               344197                        227613
# 15                               344197                        227613
# 16                               233570                        284658
# 17                               233570                        284658
# 18                               250915                        285184
# 19                               250915                        285184
# 20                                59696                        238810
# 21                                59696                        238810
# 22                               407857                        100912
# 23                               407857                        100912
# 24                               209144                        296035
# 25                               209144                        296035
# 26                               145000                        580000
# 27                               145000                        580000
# 28                               189700                        264300
# 29                               189700                        264300
#
#     assessment.totalAssessedValue  assessment.assessmentYear  \
# 0                          747160                       2021
# 1                          747160                       2021
# 2                          905000                       2021
# 3                          905000                       2021
# 4                         1260000                       2021
# 5                         1260000                       2021
# 6                          873961                       2021
# 7                          873961                       2021
# 8                          911370                       2021
# 9                          911370                       2021
# 10                         424350                       2021
# 11                         424350                       2021
# 12                         579000                       2021
# 13                         579000                       2021
# 14                         571810                       2021
# 15                         571810                       2021
# 16                         518228                       2021
# 17                         518228                       2021
# 18                         536099                       2021
# 19                         536099                       2021
# 20                         298506                       2021
# 21                         298506                       2021
# 22                         508769                       2021
# 23                         508769                       2021
# 24                         505179                       2021
# 25                         505179                       2021
# 26                         725000                       2021
# 27                         725000                       2021
# 28                         454000                       2021
# 29                         454000                       2021
#
#     building.totalBuildingAreaSquareFeet  building.yearBuilt  \
# 0                            1121.000000         1939.000000
# 1                            1121.000000         1939.000000
# 2                            1250.000000         1947.000000
# 3                            1250.000000         1947.000000
# 4                            1258.000000         1955.000000
# 5                            1258.000000         1955.000000
# 6                            1210.000000         1957.000000
# 7                            1210.000000         1957.000000
# 8                            1206.000000         1925.000000
# 9                            1206.000000         1925.000000
# 10                            600.000000         1964.000000
# 11                            600.000000         1964.000000
# 12                           1180.000000         1982.000000
# 13                           1180.000000         1982.000000
# 14                            820.000000         1986.000000
# 15                            820.000000         1986.000000
# 16                            930.000000         2007.000000
# 17                            930.000000         2007.000000
# 18                           1140.000000         2006.000000
# 19                           1140.000000         2006.000000
# 20                            528.000000         1923.000000
# 21                            528.000000         1923.000000
# 22                            680.000000         2006.000000
# 23                            680.000000         2006.000000
# 24                            950.000000         2009.000000
# 25                            950.000000         2009.000000
# 26                            910.000000         1901.000000
# 27                            910.000000         1901.000000
# 28                            730.000000         2008.000000
# 29                            730.000000         2008.000000
#
#     building.effectiveYearBuilt  ...  Floor_max_tagged  Floor_min_tagged  \
# 0                   2005.000000  ...          5.000000          2.000000
# 1                   2005.000000  ...          5.000000          2.000000
# 2                   1947.000000  ...          5.000000          2.000000
# 3                   1947.000000  ...          5.000000          2.000000
# 4                   1955.000000  ...          5.000000          2.000000
# 5                   1955.000000  ...          5.000000          2.000000
# 6                   1957.000000  ...          5.000000          2.000000
# 7                   1957.000000  ...          5.000000          2.000000
# 8                   1935.000000  ...          5.000000          2.000000
# 9                   1935.000000  ...          5.000000          2.000000
# 10                  2000.000000  ...          5.000000          2.000000
# 11                  2000.000000  ...          3.000000          2.000000
# 12                  1982.000000  ...          5.000000          2.000000
# 13                  1982.000000  ...          5.000000          2.000000
# 14                  1996.000000  ...          5.000000          3.000000
# 15                  1996.000000  ...          5.000000          2.000000
# 16                  2007.000000  ...          3.000000          2.000000
# 17                  2007.000000  ...          3.000000          2.000000
# 18                  2006.000000  ...          3.000000          2.000000
# 19                  2006.000000  ...          5.000000          3.000000
# 20                  1923.000000  ...          3.000000          2.000000
# 21                  1923.000000  ...          5.000000          3.000000
# 22                  2006.000000  ...          3.000000          3.000000
# 23                  2006.000000  ...          5.000000          2.000000
# 24                  2009.000000  ...          5.000000          3.000000
# 25                  2009.000000  ...          3.000000          3.000000
# 26                  1901.000000  ...          5.000000          2.000000
# 27                  1901.000000  ...          3.000000          2.000000
# 28                  2008.000000  ...          3.000000          2.000000
# 29                  2008.000000  ...          3.000000          2.000000
#
#     Floor_std_tagged  Floor_mean_tagged  Walls_max_tagged  Walls_min_tagged  \
# 0           1.000000           4.000000          5.000000          2.000000
# 1           1.000000           3.000000          5.000000          2.000000
# 2           1.000000           4.000000          5.000000          2.000000
# 3           1.000000           4.000000          5.000000          2.000000
# 4           1.000000           3.000000          5.000000          2.000000
# 5           1.000000           4.000000          5.000000          2.000000
# 6           1.000000           3.000000          5.000000          2.000000
# 7           1.000000           4.000000          5.000000          2.000000
# 8           1.000000           3.000000          5.000000          2.000000
# 9           1.000000           3.000000          5.000000          2.000000
# 10          1.000000           4.000000          5.000000          2.000000
# 11          1.000000           2.000000          5.000000          3.000000
# 12          1.000000           3.000000          5.000000          2.000000
# 13          1.000000           4.000000          5.000000          2.000000
# 14          1.000000           4.000000          5.000000          5.000000
# 15          1.000000           4.000000          5.000000          2.000000
# 16          1.000000           3.000000          3.000000          2.000000
# 17          1.000000           3.000000          5.000000          3.000000
# 18          1.000000           3.000000          5.000000          2.000000
# 19          1.000000           4.000000          5.000000          2.000000
# 20          1.000000           2.000000          5.000000          2.000000
# 21          1.000000           4.000000          5.000000          5.000000
# 22          0.000000           3.000000          5.000000          3.000000
# 23          1.000000           4.000000          5.000000          2.000000
# 24          1.000000           4.000000          5.000000          3.000000
# 25          0.000000           3.000000          5.000000          3.000000
# 26          1.000000           3.000000          5.000000          3.000000
# 27          1.000000           2.000000          3.000000          2.000000
# 28          1.000000           3.000000          5.000000          2.000000
# 29          1.000000           2.000000          5.000000          2.000000
#
#     Walls_std_tagged  Walls_mean_tagged  Outview_tagged  Outview_std_tagged
# 0           1.000000           5.000000        2.000000            1.000000
# 1           1.000000           4.000000        2.000000            1.000000
# 2           1.000000           4.000000        2.000000            1.000000
# 3           1.000000           3.000000        2.000000            0.000000
# 4           1.000000           4.000000        2.000000            1.000000
# 5           1.000000           4.000000        2.000000            1.000000
# 6           1.000000           4.000000        2.000000            1.000000
# 7           1.000000           3.000000        2.000000            0.000000
# 8           1.000000           4.000000        2.000000            1.000000
# 9           1.000000           3.000000        2.000000            0.000000
# 10          1.000000           4.000000        2.000000            1.000000
# 11          1.000000           4.000000        2.000000            1.000000
# 12          1.000000           4.000000        4.000000            1.000000
# 13          1.000000           4.000000        3.000000            1.000000
# 14          0.000000           5.000000        3.000000            1.000000
# 15          1.000000           4.000000        2.000000            0.000000
# 16          1.000000           3.000000        2.000000            1.000000
# 17          1.000000           4.000000        2.000000            0.000000
# 18          1.000000           3.000000        3.000000            1.000000
# 19          1.000000           3.000000        2.000000            1.000000
# 20          1.000000           4.000000        2.000000            1.000000
# 21          0.000000           5.000000        2.000000            1.000000
# 22          1.000000           4.000000        3.000000            1.000000
# 23          1.000000           4.000000        2.000000            1.000000
# 24          1.000000           4.000000        2.000000            1.000000
# 25          1.000000           4.000000        3.000000            1.000000
# 26          1.000000           5.000000        4.000000            1.000000
# 27          1.000000           3.000000        2.000000            0.000000
# 28          1.000000           3.000000        2.000000            1.000000
# 29          1.000000           3.000000        3.000000            1.000000
#
# [30 rows x 77 columns]

# %% [markdown]
# There are some really valuable features here. However, there are many redundant columns (for example, there are several data sources giving the same information, like the mls and building categories both having the building counts.) Other columns are irrelevant, as they represent id codes that can't be used, or document numbers.
#
# For some of the redundant columns though, we can still use them in order to fill in each others missing values, and only keep one of them. We will do this later.
#
# The assessment columns look extremely useful, but from an initial look, it seems like they represent some sort of data leakage. Furter research needs to be done on these columns before using them.

# %% [markdown]
# ### *In summary, we will be using the following columns for prediction and pre-processing:*

# %%
address = ['full_address', 'address.houseNumber','street', 'city',
        'state', 'zip', 'address.zipPlus4', 'sold_month'
       ] #'address.latitude', 'address.longitude'

continuous = ['building.totalBuildingAreaSquareFeet',
       # 'building.unitCount',
       'building.bedroomCount', #'building.calculatedBathroomCount'
       'building.fullBathroomCount', 'building.bathroomCount',
       'lot.lotDepthFeet', 'lot.lotSizeSquareFeet','mls.lotSizeSquareFeet', 'mls.bedroomCount', 
       'building.storyCount', 'mls.floorCount', 'mls.bathroomCount',  'building.buildingQualityCode','sale.priorSale.price', 'prev_sale_price',#'assessment.totalAssessedValue'
       'assessment.assessedImprovementValue', 'assessment.assessedLandValue',
       'bedrooms_tagged',
       'living_area_tagged',
       'Bathroom_max_tagged',
       'Bathroom_min_tagged',
       'Bathroom_std_tagged',
       'Bathroom_mean_tagged',
       'Floor_max_tagged',
       'Floor_min_tagged',
       'Floor_std_tagged',
       'Floor_mean_tagged',
       'Walls_max_tagged',
       'Walls_min_tagged',
       'Walls_std_tagged',
       'Walls_mean_tagged',
       'Outview_tagged',
       'Outview_std_tagged',
       'Kitchen_level_tagged',
       'Kitchen_level_std_tagged']

    
#Notes: Need to reverse the ordinality of the buildingQualityCode

ordinal = ['general.propertyTypeDetail'] 

one_hot = ['building.styleCode', 'building.roofCover','building.exteriorWalls', 'building.heatSource', 'building.constructionType'] #'mls.heatingTypes', 'mls.coolingTypes'

to_sparse = ['building.features', 'homeownerAssociations']

# not_sure = [ 'building.heatSourceCode'] #OneHot? What to do with new values?

# %% [markdown]
# ### b) Understanding the Target Variable

# %% [markdown]
# There are a couple of columns which relate to the Target variable:

# %%
#sale_price	prev_sale_price, sale.lastSale.price, sale.priorSale.price
targets = main_df.loc[:, ['sale.lastSale.price', 'sale.priorSale.price', 'sale_price', 'prev_sale_price']]
targets.head(10)
# Out:
#    sale.lastSale.price  sale.priorSale.price     sale_price  prev_sale_price
# 0       1030000.000000         725000.000000 1030000.000000    725000.000000
# 1       1030000.000000         725000.000000  725000.000000              NaN
# 2        905000.000000         680000.000000  905000.000000    680000.000000
# 3        905000.000000         680000.000000  680000.000000              NaN
# 4       1260000.000000         844000.000000 1260000.000000    844000.000000
# 5       1260000.000000         844000.000000  844000.000000              NaN
# 6       1317000.000000         865000.000000 1317000.000000    865000.000000
# 7       1317000.000000         865000.000000  865000.000000              NaN
# 8       1205000.000000         850000.000000 1205000.000000    540000.000000
# 9       1205000.000000         850000.000000  540000.000000              NaN

# %% [markdown]
# Our data set is comprised of two data sources regarding the target variable: The sale price and previous sale priced as collected by the data taggers, and the sale price and prev sale price as retrieved from the API call.

# %%
targets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4339 entries, 0 to 4338
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   sale.lastSale.price   4304 non-null   float64
#  1   sale.priorSale.price  4292 non-null   float64
#  2   sale_price            4339 non-null   float64
#  3   prev_sale_price       2212 non-null   float64
# dtypes: float64(4)
# memory usage: 135.7 KB

# %% [markdown]
# We can see that the taggers sale price is more filled than the API cal. However, for production, the api call is the data source which will be using. Therefore, our main target column will be the API call's sale.lastSale.price, but we will use the tagger's data to fill in any missing values.
#
# Another decision to be made, is which rows we will keep: The dataset consists of multiple sales for each house. As we can see, the oldest sale of the house doesn't have a prev_sale value. This is because the data is unknown to us (the api call only retrieves the most recent sale and prev_sale prices.) Most machine learning algorithms don't know how to calculate for null values, and therefore these rows will probably have to be dropped.
#
# A solution could be is to aggregate the information of the prev_sale row into the current sale row (such as the tagged quality of the rooms, floors, and walls).
#
# Another may be, that gradient boosting methods such as XGboost know how to account for NA values, and the rows could be salvaged there.
#
# For now we will drop the prev_sale rows, and re-evaluate after our initial modeling. First,  we wil do some quick clean up o the target variable.

# %%
# main_df = main_df.dropna(subset = ['prev_sale_price']) #drop all rows without a target value

# %% [markdown]
# #### Clean the Target Variable

# %%
def fill_current_sale_for_previous_sale(row):
    # print(row['prev_sale_price'])
    if np.isnan(row['prev_sale_price']):
        row['sale.lastSale.price'] = row['sale_price']
        row['sale.lastSale.saleDate'] = row['sale_year']
        row['sale.priorSale.price ']= None
        row['sale.priorSale.saleDate'] = None
    return row
main_df = main_df.apply(fill_current_sale_for_previous_sale, axis = 1 )

# %% [markdown]
# ##### Clean the Previous Sale Price.

# %%
#fill sale.priorSale.price with prior_sale_price
is_null = main_df[main_df['prev_sale_price'].isnull()]
df = main_df.dropna(subset = ['prev_sale_price']) #drop all rows without a target value

df['sale.priorSale.price'] = df['sale.priorSale.price'].fillna(df['prev_sale_price'])
#fill sale.priorSale.saleDate with prev_sale_date
df['sale.priorSale.saleDate'] = df['sale.priorSale.saleDate'].fillna(df['prev_sale_year'])
#where sale.lastSale.price is equal to sale.priorSale.price, fill sale.priorSale.price with lower of sale_price and prev_sale_price
def fill_sale_nulls(row):
    
    if row['sale.lastSale.price'] == row['sale.priorSale.price']:
        row['sale.priorSale.price'] = min(row['sale_price'], row['prev_sale_price'])
        try: ##HEre is just a couple of fills for the dates.
            row['sale.priorSale.saleDate'] = min(row['sale_year'], row['prev_sale_year'])
        except:
            if row['sale_year'] is None:
                row['sale.priorSale.saleDate'] = row['prev_sale_year']
            else:
                row['sale.priorSale.saleDate'] = row['sale_year']
        if row['sale.priorSale.saleDate'] is None:
            row['sale.priorSale.saleDate'] = row['sale_year']
    # except:
    #     print(row['sale.lastSale.price'], row['sale.priorSale.price'], row['sale_price'], row['prev_sale_price'])
    return row

#If sale.lastSale.price is equal to sale.priorSale.price, fill sale.priorSale.price with lower of sale_price and prev_sale_price to ensure the oldest sale is in sale.priorSale.price.
df[df['sale.lastSale.price'] == df['sale.priorSale.price']] = df[df['sale.lastSale.price'] == df['sale.priorSale.price']].apply(fill_sale_nulls, axis = 1, )

main_df = df.append(is_null).sort_index()

main_df['sale.lastSale.price'].fillna(main_df['sale_price'], inplace = True)
main_df['sale.lastSale.price'].isnull().sum()
main_df.dropna(subset = ['sale.lastSale.price'], inplace = True)

# %% [markdown]
# ##### Define the target and year features

# %%
target = ['sale.lastSale.price']
target_year = ['sale.lastSale.saleDate']
# assessments = ['sale.priorSale.price', 'assessment.totalAssessedValue'] #Assessment imprvoed, assessment land
#Assessment year MUST BE the first entryy in the list
years = [target_year[0], 'sale.priorSale.saleDate', 'assessment.assessmentYear', 'building.yearBuilt'] #'assessment.assessmentYear'
price_year_pairings = [ ('sale.priorSale.price', 'sale.priorSale.saleDate'), (target[0], target_year[0]), ('assessment.assessedImprovementValue', 'assessment.assessmentYear'), ('assessment.assessedLandValue', 'assessment.assessmentYear')] #('assessment.totalAssessedValue', 'assessment.assessmentYear'),

# %%
#show distribution of the target variable with seaborn, x axis in dollars, not log scale
import seaborn as sns
#make figsize smaller
plt.figure(figsize = (10, 8))
sns.histplot(main_df[target[0]], bins = 50)
#make xticks to be linspace of min and max in integer values
plt.xticks(np.linspace(main_df[target[0]].min(), main_df[target[0]].max(), 5), labels = np.linspace(main_df[target[0]].min(), main_df[target[0]].max(), 5).astype(int));

# %% [markdown]
# ##### Create the Dataframe we will work with

# %%
features = [address, continuous, ordinal, years, target, one_hot, to_sparse]
features = [x for y in features for x in y]
print( f' df rows: {main_df.shape[0]}, columns: {len(features)}')
# Out:
#  df rows: 4339, columns: 55

# %%
df = main_df.loc[:, features]
df
# Out:
#                                            full_address  address.houseNumber  \
# 0     3913 York Boulevard, Los Angeles, CA 90065 Sol...                 3913
# 1     3913 York Boulevard, Los Angeles, CA 90065 Sol...                 3913
# 2     4171 Division Street, Los Angeles, CA 90065 So...                 4171
# 3     4171 Division Street, Los Angeles, CA 90065 So...                 4171
# 4     4234 Palmero Drive, Los Angeles, CA 90065 Sold...                 4234
# ...                                                 ...                  ...
# 4334  2013 N Corlett Avenue, Los Angeles, CA 90059 S...                 2013
# 4335  2307 E 120th St, Los Angeles, CA 90059 Sold Au...                 2307
# 4336  2307 E 120th Street, Los Angeles, CA 90059 Sol...                 2307
# 4337  11709 Compton Avenue, Los Angeles, CA 90059 So...                11709
# 4338  11709 Compton Avenue, Los Angeles, CA 90059 So...                11709
#
#                   street         city state    zip  address.zipPlus4  \
# 0         3913 york blvd  los angeles    ca  90065              3718
# 1         3913 york blvd  los angeles    ca  90065              3718
# 2       4171 division st  los angeles    ca  90065              4205
# 3       4171 division st  los angeles    ca  90065              4205
# 4        4234 palmero dr  los angeles    ca  90065              4251
# ...                  ...          ...   ...    ...               ...
# 4334  2013 n corlett ave  los angeles    ca  90059              3626
# 4335     2307 e 120th st  los angeles    ca  90059              2629
# 4336     2307 e 120th st  los angeles    ca  90059              2629
# 4337   11709 compton ave  los angeles    ca  90059              1826
# 4338   11709 compton ave  los angeles    ca  90059              1826
#
#      sold_month  building.totalBuildingAreaSquareFeet  building.bedroomCount  \
# 0           may                           1121.000000               2.000000
# 1           may                           1121.000000               2.000000
# 2      december                           1250.000000               2.000000
# 3          july                           1250.000000               2.000000
# 4     september                           1258.000000               2.000000
# ...         ...                                   ...                    ...
# 4334   december                           1796.000000               4.000000
# 4335     august                            753.000000               2.000000
# 4336   november                            753.000000               2.000000
# 4337      march                            744.000000               4.000000
# 4338       july                            744.000000               4.000000
#
#       ...  assessment.assessmentYear  building.yearBuilt  sale.lastSale.price  \
# 0     ...                       2021         1939.000000       1030000.000000
# 1     ...                       2021         1939.000000        725000.000000
# 2     ...                       2021         1947.000000        905000.000000
# 3     ...                       2021         1947.000000        680000.000000
# 4     ...                       2021         1955.000000       1260000.000000
# ...   ...                        ...                 ...                  ...
# 4334  ...                       2021         1945.000000        200000.000000
# 4335  ...                       2021         1915.000000        560000.000000
# 4336  ...                       2021         1915.000000        335000.000000
# 4337  ...                       2021         1927.000000        255000.000000
# 4338  ...                       2021         1927.000000        255000.000000
#
#       building.styleCode   building.roofCover  building.exteriorWalls  \
# 0              15.000000  Composition Shingle                  Stucco
# 1              15.000000  Composition Shingle                  Stucco
# 2              15.000000  Composition Shingle                  Stucco
# 3              15.000000  Composition Shingle                  Stucco
# 4              15.000000  Composition Shingle                  Stucco
# ...                  ...                  ...                     ...
# 4334                 NaN                  NaN                     NaN
# 4335                 NaN                  NaN                     NaN
# 4336                 NaN                  NaN                     NaN
# 4337           15.000000  Composition Shingle                  Stucco
# 4338           15.000000  Composition Shingle                  Stucco
#
#       building.heatSource  building.constructionType  \
# 0                 Central                       Wood
# 1                 Central                       Wood
# 2              Floor/Wall                       Wood
# 3              Floor/Wall                       Wood
# 4                 Central                       Wood
# ...                   ...                        ...
# 4334           Floor/Wall                       Wood
# 4335                  NaN                       Wood
# 4336                  NaN                       Wood
# 4337           Floor/Wall                       Wood
# 4338           Floor/Wall                       Wood
#
#                       building.features  \
# 0     ['Air Conditioning', 'Fireplace']
# 1     ['Air Conditioning', 'Fireplace']
# 2                                    []
# 3                                    []
# 4                         ['Fireplace']
# ...                                 ...
# 4334                                 []
# 4335                                 []
# 4336                                 []
# 4337                                 []
# 4338                                 []
#
#                                   homeownerAssociations
# 0     [{'type': 'PUD', 'feeAmount': 1200, 'feeFreque...
# 1     [{'type': 'PUD', 'feeAmount': 1200, 'feeFreque...
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 4334  [{'type': 'HOA', 'feeAmount': 400, 'feeFrequen...
# 4335  [{'type': 'HOA', 'feeAmount': 300, 'feeFrequen...
# 4336  [{'type': 'HOA', 'feeAmount': 300, 'feeFrequen...
# 4337  [{'type': 'HOA', 'feeAmount': 700, 'feeFrequen...
# 4338  [{'type': 'HOA', 'feeAmount': 700, 'feeFrequen...
#
# [4339 rows x 55 columns]

# %% [markdown]
# ### c) Simple Imputation and Feature Cleaning

# %% [markdown]
# #### Drop rows where target value is missing

# %%
df.dropna(subset = [target[0], target_year[0]], inplace= True) #drop all rows without a target value
df.replace('nan', np.nan, inplace = True) #replace all 'nan' strings with np.nan
df.shape[0]
# Out:
# 4334

# %% [markdown]
# #### Fix "Year" Features (make them all integer format, and not datetime)

# %%
def take_year(x):
    try:
        x = x.split('-')
        x = int(x[0])
    except:
        x = int(float(x))
    return x

current_year = int(date.today().year)
for year in years:
    print(year)
    
    #if year is an integer, fillna with mode. If year is a float, convert to int while handling the nan values.
    if df[year].dtype == 'int64':
        print('int64')
        df[year].fillna(df[year].mode()[0], inplace = True)
    elif df[year].dtype == 'float64':
        print('float64')
        df[year].fillna(df[year].mode()[0], inplace = True)
        df[year] = df.loc[:, year].astype(int)
        # df[df[year] > current_year] = current_year
    elif df[year].dtype == 'object':
        try:
            print('object')
            df[year].fillna(df[year].mode()[0], inplace=True)
            df[year] = df.loc[:, year].astype(int)

        except:
            print('else')
            df[year].fillna(df[year].mode()[0], inplace=True) #If not numerical, than apply the take_year function
            df[year] = df[year].apply(take_year)
            df.loc[:, year] = df.loc[:, year].astype(int)
    
    #drop row if length of the year string is not 4
    for x in df[year]:
        if len(str(x))<4 or len(str(x))>4:
            df.drop(df[df[year] == x].index, inplace = True)
        # df[df[year] > current_year] = current_year
# Out:
# sale.lastSale.saleDate
# object
# else
# sale.priorSale.saleDate
# object
# else
# assessment.assessmentYear
# int64
# building.yearBuilt
# float64

# %% [markdown]
# #### Adjust Prices for Inflation

# %%
#Apply current price adjusted for inflation
from datetime import datetime
import cpi
def apply_cpi(x, price_col, year_col):
    if pd.isnull(x.loc[price_col]) == False or x.loc != None:
        price = x.loc[price_col]
        year = x.loc[year_col]
        month_names = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
        month = x.loc['sold_month'][:3].lower()
        if month not in month_names:
            month = 'jan'
        if year == 2022 and month =='dec':
            month = 'nov'
        #convert month to its numerical value
        date_string = f"{year} {month}"
        date = datetime.strptime(date_string, "%Y %b")

        # if year != current_year:
            # print(price, year)
            #combine year and month to datetime format to get the correct CPI value
        # year = str(year) + '-' + str(month)
        val = cpi.inflate(price, date, items= 'Housing', )
        x.loc[price_col] = val
        return x
# df = df.apply(apply_cpi, args = ('sale.lastSale.price', 'sale.lastSale.saleDate'), axis = 1)
# df = df.apply(apply_cpi, args = ('assessment.totalAssessedValue', 'assessment.assessmentYear'), axis = 1)
for pair in price_year_pairings:
    print(pair)
    df = df.apply(apply_cpi, args = (pair), axis =1)
# Out:
# ('sale.priorSale.price', 'sale.priorSale.saleDate')
# ('sale.lastSale.price', 'sale.lastSale.saleDate')
# ('assessment.assessedImprovementValue', 'assessment.assessmentYear')
# ('assessment.assessedLandValue', 'assessment.assessmentYear')

# %% [markdown]
# #### Sparse House and HOA Features

# %% [markdown]
# There are two columns with valuable features, but their columns contain dictionaries with multiple features:

# %%
to_sparse
# Out:
# ['building.features', 'homeownerAssociations']

# %% [markdown]
# To fix this, we just need to do a quick sparsing of the features:

# %%
houses_features = []
a = df.loc[:,['building.features']].values
for x in a:
    features_dict = {'AC': 0, 'Fireplace': 0, 'SolarHeat': 0, 'EvaporativeCooler': 0, 'AttachedGarage': 0, 'SpaorHotTub': 0, 'Spa': 0, 'Pool': 0, 'Garage': 0}
    for y in x:
        attr = y.replace("[", "").replace("]", "").replace("'", "").replace(" ", "").split(",")
        for item in attr:
            if "Conditioning" in item:
                if "Wall" in item:
                    features_dict['AC'] = 1
                elif "Central" in item:
                    features_dict['AC'] = 3
                else:
                    features_dict['AC'] = 2
            else:
                features_dict[item] = 1
    houses_features.append(features_dict)
features_df = pd.DataFrame(houses_features)
df = df.join(features_df).drop(['building.features'], axis = 1)

# %% [markdown]
# ##### Now the HOA column

# %%
#grab the "type" and "amount" from the homeownerAssociations column. The column contains a dictionary with those two values

def get_hoa_type(x):
    if pd.isnull(x) == False:
        x = x.replace("[", "").replace("]", "").replace("'", "").replace(" ", "").split(",")
        for item in x:
            if 'type' in item:
                hoa = item.split(":")[1].replace("'", "").replace("}", "")
                return hoa
    else:
        return np.nan

def get_hoa_amount(x):
    if pd.isnull(x) == False:
        x = x.replace("[", "").replace("]", "").replace("'", "").replace(" ", "").split(",")
        for item in x:
            if 'feeAmount' in item:
                amount = int(item.split(":")[1].replace("'", "").replace("}", ""))
                return amount

    else:
        return np.nan

df['hoa_type'] = df.homeownerAssociations.apply(get_hoa_type)
df['hoa_amount'] = df.homeownerAssociations.apply(get_hoa_amount)
df.drop('homeownerAssociations', axis = 1, inplace = True)

# %% [markdown]
# #### d) Row Wise Fill of null values
#
# ##### Normally it is ideal to wait until train and tests splits to fill in null values, as to not cause a data leak of the test set into the train set. That is why we now are only going to fill in features whose Null values can be filled by other features in their own row.

# %%
missing = df.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing = missing/df.shape[0]
missing
# Out:
# building.fullBathroomCount             0.000462
# building.bathroomCount                 0.000462
# living_area_tagged                     0.000693
# building.totalBuildingAreaSquareFeet   0.000924
# building.bedroomCount                  0.000924
# lot.lotSizeSquareFeet                  0.001386
# EvaporativeCooler                      0.002310
# SolarHeat                              0.002310
# Fireplace                              0.002310
# AC                                     0.002310
# Spa                                    0.002310
# AttachedGarage                         0.002310
# Pool                                   0.002310
# Garage                                 0.002310
# SpaorHotTub                            0.002310
# building.constructionType              0.002772
# sale.priorSale.price                   0.005313
# building.buildingQualityCode           0.012705
# mls.bathroomCount                      0.016632
# mls.bedroomCount                       0.016632
# building.heatSource                    0.049203
# Kitchen_level_tagged                   0.052668
# Kitchen_level_std_tagged               0.052668
# mls.lotSizeSquareFeet                  0.093555
# mls.floorCount                         0.164934
# hoa_type                               0.235851
# building.styleCode                     0.267036
# building.storyCount                    0.268653
# hoa_amount                             0.309771
# lot.lotDepthFeet                       0.334719
# building.roofCover                     0.424116
# prev_sale_price                        0.490182
# building.exteriorWalls                 0.491568
#                                        0.615154
# DetachedGarage                         0.946177
# Underground/BasementGarage             0.996997
# SolarHeatedPool                        0.999538
# Porch                                  0.999538
# dtype: float64

# %%
df.loc[:, 'mls.floorCount'].fillna(df.loc[:, 'building.storyCount'], inplace = True)
df.drop(['building.storyCount'], axis = 1, inplace = True)

df.loc[:, 'mls.bathroomCount'].fillna(df.loc[:, 'building.bathroomCount'], inplace = True)
df.drop(['building.bathroomCount'], axis = 1, inplace = True)

df.loc[:, 'mls.bedroomCount'].fillna(df.loc[:, 'building.bedroomCount'], inplace = True)
df.drop(['building.bedroomCount'], axis = 1, inplace = True)

df.loc[:, 'mls.lotSizeSquareFeet'].fillna(df.loc[:, 'lot.lotSizeSquareFeet'], inplace = True)
df.drop(['lot.lotSizeSquareFeet'], axis = 1, inplace = True)

df.loc[:, 'living_area_tagged'].fillna(df.loc[:, 'building.totalBuildingAreaSquareFeet'], inplace = True)
df.drop(['building.totalBuildingAreaSquareFeet'], axis = 1, inplace = True)
df.drop('', axis = 1, inplace = True)

# %%
# fill in missing values with the mode of the building exterior walls
df.loc[:, 'building.exteriorWalls'].fillna(df.loc[:, 'building.exteriorWalls'].mode()[0], inplace = True)

# %%
#Fill Kitchen_level_tagged with average value
df.loc[:, 'Kitchen_level_tagged'].fillna(df.loc[:, ['Bathroom_mean_tagged', 'Floor_mean_tagged', 'Walls_mean_tagged']].mean(axis = 1), inplace = True)
df.loc[:, 'Kitchen_level_std_tagged'].fillna(df.loc[:, ['Bathroom_std_tagged', 'Floor_std_tagged', 'Walls_std_tagged']].mean(axis = 1), inplace = True)

# %%
##### We are also going to drop a few columns, as almost all of the values are 0 or null
#drop porc soloarheat and underground/basement garage, only if they exist as columns
for col in ['Porch', 'SolarHeatedPool', 'Underground/BasementGarage', 'DetachedGarage']:
    cols = df.columns
    if col in cols:
        df.drop(col, axis = 1, inplace = True)

# %% [markdown]
# For the hoa type and the hoa amount, we can assume they are null intentionally-- they don't belong to an hoa.

# %%
#fill hoa_amount with 0, and hoa type with 'None'
df.loc[:, 'hoa_amount'].fillna(0, inplace = True)
df.loc[:, 'hoa_type'].fillna('None', inplace = True)

# %% [markdown]
# #### For the rest of the features, there isn't any specific explanation as to why they are missing. Therefore later, we will use more advanced imputation methods to fill them, once we split the dataset into train and test.

# %% [markdown]
# #### Check for Skew

# %%
#Perform basic EDA on the dataset
df.hist(bins=50, figsize=(20,18))
plt.show()

# %% [markdown]
# A couple of the features here look skewed at first sight. But further understanding of the features shows that the apparent skew is more likely to do errant values. For example, the mls.floorCount feature is normal in the beginning, but then widens out to values which are unrealistic for floor counts.
#
# Similarly with the hoa_amount. The large values might be due to the fact that the large amounts are yearly aggregates, as opposed to monthly aggregates like the rest of the rows.
#
# These features should be handled with outlier removal.
#
# **The skews which do seem to exist are in the pricing features, such as the target and the prior sale. It very well could be that fixing their skew could help.**

# %% [markdown]
# #### Coorelations to the Target Variable

# %%
#more eda
import seaborn as sns

#show coorelations to the sale.lastSale.price variable where the correlation is greater than 0.5
corr_matrix = df.corr()
corr_matrix["sale.lastSale.price"].sort_values(ascending=False)
#now show only the coorelations that are greater than 0.5
corr_matrix["sale.lastSale.price"][corr_matrix["sale.lastSale.price"].abs() > 0.4].sort_values(ascending=False)
# Out:
# sale.lastSale.price                   1.000000
# sale.priorSale.price                  0.954254
# prev_sale_price                       0.951158
# assessment.assessedLandValue          0.865435
# assessment.assessedImprovementValue   0.784713
# living_area_tagged                    0.708997
# building.fullBathroomCount            0.543087
# mls.bathroomCount                     0.542939
# bedrooms_tagged                       0.444702
# mls.bedroomCount                      0.429212
# Name: sale.lastSale.price, dtype: float64

# %% [markdown]
# The living area, bathroom count, and bedroom count seem to have the largest coorelations with the target variable.

# %% [markdown]
# ## 2)Feature Engineering

# %% [markdown]
# Aggregation filling

# %% [markdown]
# #### Create Age Column

# %%
df['age'] = df['sale.lastSale.saleDate'] - df['building.yearBuilt']

# %% [markdown]
# #### Create Overall Quality and average quality columns

# %%
df['overall_quality'] = df[['Kitchen_level_tagged', 'Bathroom_mean_tagged', 'Floor_mean_tagged', 'Walls_mean_tagged', 'Outview_tagged']].mean(axis=1)
df['average_std_tagged'] = df[['Bathroom_std_tagged', 'Floor_std_tagged', 'Walls_std_tagged', 'Outview_std_tagged', 'Kitchen_level_std_tagged']].mean(axis=1)
df['average_max_tagged'] = df[['Bathroom_max_tagged', 'Floor_max_tagged', 'Walls_max_tagged']].mean(axis=1)
df['average_min_tagged'] = df[['Bathroom_min_tagged', 'Floor_min_tagged', 'Walls_min_tagged']].mean(axis=1)

# %% [markdown]
# #### One Hot Encoding

# %%
df = pd.get_dummies(df, columns= one_hot)

# %% [markdown]
# #### Ordinal Encoding

# %%
ordinal.append('hoa_type')

# %%
from sklearn.preprocessing import OrdinalEncoder
# df.loc[:, ordinal] = ord.fit_transform(df['building.buildingQualityCode'].values.reshape(len(df['building.buildingQualityCode']), 1))
ord_encoders = {}
for col in ordinal:
    ord = OrdinalEncoder(handle_unknown= 'use_encoded_value', unknown_value= len(df[col]) +1)
    ord_encoders[col] = ord
    df[col] = ord.fit_transform(df[col].values.reshape(len(df[col]), 1))

# for col in ordinal:
#     df[col] = ord_encoders[col].transform(df[col])

# %% [markdown]
# #### Outlier Removal: Remove all rows where chosen feature has a zscore of less than X amount

# %%
df.shape
# Out:
# (4329, 95)

# %%
#create a grid search for an SVR model

# %%
from scipy import stats
statcols = ['sale.lastSale.price']
# df['statcol'] = df[target] - df[target]
statcols = ['sale.lastSale.price', 'living_area_tagged']
abs_z_scores = np.abs(stats.zscore(df[statcols]))
filtered_entries = (abs_z_scores < 3.5).all(axis=1)
train = df[filtered_entries]
# train.drop(['statcol'], axis = 1, inplace = True)
#drop target lower than 100000
train = train[train['sale.lastSale.price'] > 100000]

#if hoa is above 2000, divide by 12
train.loc[train['hoa_amount'] > 2000, 'hoa_amount'] = train.loc[train['hoa_amount'] > 2000, 'hoa_amount']/12

# %%
#Show the distributions after we removed teh outliers
statcols.append('hoa_amount')
fig, ax = plt.subplots(1, len(statcols), figsize = (20, 5))
for i, col in enumerate(statcols):
    sns.histplot(train[col], ax = ax[i])
plt.show()

# %% [markdown]
# #### Fix the Skewed Features

# %%
train['assessment.assessedImprovementValue'] = np.log1p(train['assessment.assessedImprovementValue'])
train['assessment.assessedLandValue'] = np.log1p(train['assessment.assessedLandValue'])
train['sale.priorSale.price'] = np.log1p(train['sale.priorSale.price'])

# %% [markdown]
# ## 3)Final Data Preperations

# %% [markdown]
# #### Fix the Skews, Min-Max Scaling, KNN imputation, Drop Unrelated Columns, Train Test Splits

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer


def process_data(train_df, with_prev_sales):
    if with_prev_sales==False:
        train_df = train_df.dropna(subset = ['prev_sale_price'])
    #drop columns that are address related
    train_df = train_df.loc[:, ~train_df.columns.str.contains('^address')]
    train_df = train_df.drop(['full_address','street', 'city', 'state', 'zip'], axis = 1)
    
    #drop years (if calculated the age)
    train_df = train_df.drop(years, axis =1)
    if with_prev_sales==False:
        train_df = train_df.drop(['prev_sale_price', 'sold_month'], axis = 1) #drop prev_sale_price, as we use the sale.priorSale.price
    #split target
    target = train_df.loc[:, 'sale.lastSale.price']
    train_df = train_df.drop(['sale.lastSale.price'], axis = 1)

    #Train test splits
    #if with_prev_sales==True, stratify on if the prev_sale_price is null or not
    if with_prev_sales==True:
        x_train, x_test, y_train, y_test = train_test_split(train_df, target, test_size=0.2, random_state=42, stratify = train_df['prev_sale_price'].isnull())
        x_train = x_train.drop(['prev_sale_price', 'sold_month'], axis = 1)
        x_test = x_test.drop(['prev_sale_price', 'sold_month'], axis = 1)
    else:
        x_train, x_test, y_train, y_test = train_test_split(train_df, target, test_size=0.2, random_state=42)
    columns = x_train.columns
    #MinMaxScaling
    scaler = MinMaxScaler()
    x_train = scaler.fit_transform(x_train)
    x_test = scaler.transform(x_test)

    #KNN Imputation
    imputer = KNNImputer(n_neighbors=3)
    imputer.fit(x_train)
    x_train = pd.DataFrame(imputer.transform(x_train), columns=columns)
    x_test = pd.DataFrame(imputer.transform(x_test), columns=columns)

    return x_train, x_test, y_train, y_test

# %% [markdown]
# ## 4)Modeling

# %%
import xgboost
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, median_absolute_error
### MEan absolute percentage error: np.mean(np.abs((y_true - y_pred) / y_true))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import RidgeCV,Ridge
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNetCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

import warnings
warnings.filterwarnings('ignore', module='sklearn')

def get_metrics(y_test, y_pred):
    mae = mean_absolute_error(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    mape = mean_absolute_percentage_error(y_test, y_pred)
    return pd.Series({'Mean Abs. Error': mae, 'Root Mean Squared Error': rmse, 'Mean Percentage Error': mape})

def model_training(x_train, x_test, y_train, y_test):

    #Set the parameters for the grid search
    ridge_alphas = [0.005, 0.05, 0.1, 1, 3, 5, 10, 100]
    lasso_alphas = [0.005, 0.05, 0.1, 1, 3, 5, 10, 100]
    elastic_l1_ratios = [0.005, 0.05, 0.1, 1, 3, 5, 10, 100]
    #parameters for random forest
    svr_param_grid={"kernel" : ["rbf", "poly"], 'degree':[3,4,5],
                    "C": [0.01, 0.1, 1, 10, 100], 
                    "gamma": [0.01, 0.1, 1, 10, 100]}
    dt_grid = {'max_depth': [3, 5, 10,20, 30],
                'min_samples_split': [2, 3, 5, 10]}
    rf_param_grid = {'n_estimators': [100, 200, 300, 400, 500],
                    'max_depth': [3, 5, 10, 20],
                    'min_samples_split': [2, 5, 10]}


    #Instantiate the Grid Searches
    ridgeCV = RidgeCV(alphas=ridge_alphas,store_cv_values=True)
    lassoCV = LassoCV(alphas=lasso_alphas, cv=5)
    elasticNetCV = ElasticNetCV(alphas=lasso_alphas, l1_ratio=elastic_l1_ratios, cv=5)
    svr  = GridSearchCV(SVR(), svr_param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
    dt = GridSearchCV(DecisionTreeRegressor(), dt_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
    rf = GridSearchCV(RandomForestRegressor(), rf_param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
    #Fit the Grid Searches
    ridgeCV.fit(x_train, y_train)
    lassoCV.fit(x_train, y_train)
    elasticNetCV.fit(x_train, y_train)
    svr.fit(x_train, y_train)
    dt.fit(x_train, y_train)
    rf.fit(x_train, y_train)

    #Get the predictions
    y_ridgecv=ridgeCV.predict(x_test)
    y_lasso=lassoCV.predict(x_test)
    y_elastic=elasticNetCV.predict(x_test)
    y_svr = svr.predict(x_test)
    y_dt = dt.predict(x_test)
    y_rf = rf.predict(x_test)
    
    #Get the metrics
    ridgeCV_results = get_metrics(y_test, y_ridgecv)
    lassoCV_results = get_metrics(y_test, y_lasso)
    elasticNetCV_results = get_metrics(y_test, y_elastic)
    svr_results = get_metrics(y_test, y_svr)
    dt_results = get_metrics(y_test, y_dt)
    rf_results = get_metrics(y_test, y_rf)
    labels = ['Ridge', 'Lasso', 'ElasticNet','SVR', 'Decision Tree', 'Random Forest']

    #Make a dataframe of the results
    rmse_df = pd.DataFrame([ridgeCV_results, lassoCV_results, elasticNetCV_results, svr_results, dt_results, rf_results], index=labels)
    return rmse_df

def get_xgboost(x_train, x_test, y_train, y_test):
    params = {
        'max_depth': [4, 5, 6,7],
        'learning_rate': [0.03, 0.1, 0.3],
        'n_estimators': [100, 200, 250,300, 400, 500, 800, 1000],
        'min_child_weight': [2, 3, 5, 10]
        }
    xgboost_model = GridSearchCV(xgboost.XGBRegressor(objective='reg:squarederror'), params, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
    xgboost_model.fit(x_train, y_train)
    y_pred = xgboost_model.predict(x_test)
    #make dataframe from the results Series
    results = pd.DataFrame(get_metrics(y_test, y_pred), columns=['Results']).transpose()
    return results, xgboost_model.best_estimator_, xgboost_model.best_params_

# %% [markdown]
# ### Modeling **With Out** Previous Sales
#
# ##### Our machine learning models are not able to learn with Null values. Therefore we need to drop the rows iwth null values in the prev_sale_price column

# %%
x_train, x_test, y_train, y_test = process_data(train, with_prev_sales=False)

rmse_df = model_training(x_train, x_test, y_train, y_test)
rmse_df
# Out:
#                Mean Abs. Error  Root Mean Squared Error  Mean Percentage Error
# Ridge            124123.654009            175110.663724               0.162599
# Lasso            123363.220542            172321.197032               0.163607
# ElasticNet       123886.213836            174377.973750               0.162715
# SVR              105072.254931            150933.593921               0.130194
# Decision Tree     98753.487191            148070.903456               0.123983
# Random Forest     72368.894487            122207.938076               0.089981

# %%
xgboost_results, xgb, best_params= get_xgboost(x_train, x_test, y_train, y_test)
print('XGBOOST results:')
print(best_params)
xgboost_results
# Out:
# XGBOOST results:
# {'colsample_bytree': 1.0, 'learning_rate': 0.03, 'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 300}
#          Mean Abs. Error  Root Mean Squared Error  Mean Percentage Error
# Results     77592.227528            124145.712005               0.096088

# %% [markdown]
# ### Modeling **With** Previous Sales - XGBoost
#
# ##### As we mentioned, XGBoost is able to handle the null values of the previous sales, unlike the other Alogorithms. Lets try that now:

# %%
x_train, x_test, y_train, y_test = process_data(train, with_prev_sales=True)

xgboost_results, xgb, best_params= get_xgboost(x_train, x_test, y_train, y_test)

print('XGBOOST results')
print(best_params)
xgboost_results
# Out:
# XGBOOST results
# {'colsample_bytree': 1.0, 'learning_rate': 0.03, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 250}
#          Mean Abs. Error  Root Mean Squared Error  Mean Percentage Error
# Results     84210.684018            128145.831578               0.115259

# %%
#plot feature importance
xgboost.plot_importance(xgb)
plt.rcParams['figure.figsize'] = [16, 12]
plt.show()

# %% [markdown]
# ## 5)Utilitizing the Historical Data Qualities
#
# Up until this point, we haven't really utilized the historical quality of our data. Each row has been its own seperate piece of information. Now, we will try to bring the information of a house's previous sale into its current sale, and see if the model can learn better from the historical data.

# %%
train.reset_index(inplace=True, drop=True)

# %%
df_dropped_na = train.dropna(subset = ['full_address', 'address.houseNumber', 'street', 'city',
        'state', 'zip', 'Bathroom_max_tagged',
 'Bathroom_min_tagged',
 'Bathroom_std_tagged',
 'Bathroom_mean_tagged',
 'Floor_max_tagged',
 'Floor_min_tagged',
 'Floor_std_tagged',
 'Floor_mean_tagged',
 'Walls_max_tagged',
 'Walls_min_tagged',
 'Walls_std_tagged',
 'Walls_mean_tagged',
 'Outview_tagged',
 'Outview_std_tagged',
 'Kitchen_level_tagged',
 'Kitchen_level_std_tagged'], axis = 0)

# %%
dub_addresses = df_dropped_na[df_dropped_na[['street']].duplicated(['street'])]['street']
dub_df = df_dropped_na.loc[df_dropped_na['street'].isin(dub_addresses)]
dub_df.shape
# Out:
# (4245, 95)

# %% [markdown]
# Group By's (condition differences, price differences) To validate that there is deviation

# %%
dub_df.groupby(['street'])[['Bathroom_max_tagged',
 'Bathroom_min_tagged',
 'Bathroom_std_tagged',
 'Bathroom_mean_tagged',
 'Floor_max_tagged',
 'Floor_min_tagged',
 'Floor_std_tagged',
 'Floor_mean_tagged',
 'Walls_max_tagged',
 'Walls_min_tagged',
 'Walls_std_tagged',
 'Walls_mean_tagged',
 'Outview_tagged',
 'Outview_std_tagged']].std().head(5)
# Out:
#                      Bathroom_max_tagged  Bathroom_min_tagged  \
# street
# 1001 w 132nd st                 1.414214             0.000000
# 10012 s gramercy pl             2.121320             0.000000
# 10013 westwanda dr              0.000000             0.000000
# 10032 pangborn ave              2.121320             0.707107
# 10037 beach st                  0.707107             1.414214
#
#                      Bathroom_std_tagged  Bathroom_mean_tagged  \
# street
# 1001 w 132nd st                 0.707107              0.707107
# 10012 s gramercy pl             0.707107              1.414214
# 10013 westwanda dr              0.000000              0.707107
# 10032 pangborn ave              0.707107              1.414214
# 10037 beach st                  0.707107              0.000000
#
#                      Floor_max_tagged  Floor_min_tagged  Floor_std_tagged  \
# street
# 1001 w 132nd st              1.414214          0.000000          0.000000
# 10012 s gramercy pl          0.000000          0.707107          0.000000
# 10013 westwanda dr           0.000000          0.000000          0.000000
# 10032 pangborn ave           0.000000          0.000000          0.000000
# 10037 beach st               0.000000          0.707107          0.707107
#
#                      Floor_mean_tagged  Walls_max_tagged  Walls_min_tagged  \
# street
# 1001 w 132nd st               0.707107          0.000000          0.000000
# 10012 s gramercy pl           0.707107          0.000000          0.000000
# 10013 westwanda dr            0.707107          0.000000          0.000000
# 10032 pangborn ave            0.000000          1.414214          0.000000
# 10037 beach st                0.000000          1.414214          0.707107
#
#                      Walls_std_tagged  Walls_mean_tagged  Outview_tagged  \
# street
# 1001 w 132nd st              0.000000           0.000000        0.000000
# 10012 s gramercy pl          0.000000           0.000000        0.000000
# 10013 westwanda dr           0.000000           0.707107        0.707107
# 10032 pangborn ave           0.000000           0.707107        0.000000
# 10037 beach st               0.707107           0.000000        0.000000
#
#                      Outview_std_tagged
# street
# 1001 w 132nd st                0.000000
# 10012 s gramercy pl            0.000000
# 10013 westwanda dr             0.000000
# 10032 pangborn ave             0.707107
# 10037 beach st                 0.000000

# %%
columns = ['full_address', 'address', 'sale_between', 'Bathroom_max_tagged',
 'Bathroom_min_tagged',
 'Bathroom_std_tagged',
 'Bathroom_mean_tagged',
 'Floor_max_tagged',
 'Floor_min_tagged',
 'Floor_std_tagged',
 'Floor_mean_tagged',
 'Walls_max_tagged',
 'Walls_min_tagged',
 'Walls_std_tagged',
 'Walls_mean_tagged',
 'Outview_tagged',
 'Outview_std_tagged',
 'Kitchen_level_tagged',
 'Kitchen_level_std_tagged','overall_quality',
 'average_std_tagged', 'average_max_tagged',
       'average_min_tagged']

aggregation_columns = ['Bathroom_max_tagged',
 'Bathroom_min_tagged',
 'Bathroom_std_tagged',
 'Bathroom_mean_tagged',
 'Floor_max_tagged',
 'Floor_min_tagged',
 'Floor_std_tagged',
 'Floor_mean_tagged',
 'Walls_max_tagged',
 'Walls_min_tagged',
 'Walls_std_tagged',
 'Walls_mean_tagged',
 'Outview_tagged',
 'Outview_std_tagged',
 'Kitchen_level_tagged',
 'Kitchen_level_std_tagged',
 'overall_quality',
 'average_std_tagged', 'average_max_tagged',
       'average_min_tagged']
 
difference_df = pd.DataFrame(columns = columns)
dub_df = dub_df.sort_values(by = ['street', 'sale.lastSale.saleDate']).reset_index(drop=True)

# %% [markdown]
# #### Group the Dataframe by its address and its sales, and gather the historical data

# %%
list_of_data = []
for house in dub_df['street'].unique():
    house_df = dub_df[dub_df['street'] == house].sort_values(by = ['sale.lastSale.saleDate'], ascending = False)
    sale_b_idx = 0
    for i, sale_a in house_df.iterrows():
        sale_b_idx +=1 
        if sale_b_idx < len(house_df):
            sale_b = house_df.iloc[sale_b_idx]
            data_point = dict()
            data_point['full_address'] = sale_a['full_address']
            data_point['time_between_sales'] = int(sale_a['sale.lastSale.saleDate']) - int(sale_b['sale.lastSale.saleDate'])
            for col in aggregation_columns: #Calculate the differences between the quality columns.
                data_point[f'difference_{col}'] = int(sale_a[col]) - int(sale_b[col])
            list_of_data.append(data_point)
        else:

            data_point = dict()
            data_point['full_address'] = sale_a['full_address']
            data_point['time_between_sales'] = int(sale_a['sale.lastSale.saleDate']) - int(sale_b['sale.lastSale.saleDate'])
            for col in aggregation_columns:
                data_point[f'difference_{col}'] = np.nan
            list_of_data.append(data_point)

difference_df = pd.DataFrame.from_records(list_of_data)

# %%
#feature names must be unique
diff_df = dub_df.merge(difference_df, left_index=True, right_index=True, suffixes=('', '_diff')) 
#drop columns ending in _diff
diff_df = diff_df.loc[:,~diff_df.columns.str.endswith('_diff')]

# %% [markdown]
# #### Trying the model again, dropping the rows with the previous sale prices

# %%
x_train, x_test, y_train, y_test = process_data(diff_df, with_prev_sales=False)

# %%
rmse_df = model_training(x_train, x_test, y_train, y_test)
rmse_df
# Out:
#                Mean Abs. Error  Root Mean Squared Error  Mean Percentage Error
# Ridge            135877.284223            186654.906299               0.173704
# Lasso            135655.888770            186606.206856               0.175103
# ElasticNet       135613.863359            186151.335459               0.173590
# SVR              103137.593954            156412.440868               0.123858
# Decision Tree     97440.080179            145368.655005               0.114446
# Random Forest     74489.409227            120811.527132               0.088822

# %%
xgboost_results, xgb, best_params= get_xgboost(x_train, x_test, y_train, y_test)
print('XGBOOST results')
print(best_params)
xgboost_results
# Out:
# XGBOOST results
# {'colsample_bytree': 1.0, 'learning_rate': 0.03, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 250}
#          Mean Abs. Error  Root Mean Squared Error  Mean Percentage Error
# Results     72340.356478            114115.548546               0.087804

# %% [markdown]
# ### Trying again **With** the previous sales

# %%
x_train, x_test, y_train, y_test = process_data(diff_df, with_prev_sales=True)
xgboost_results, xgb, best_params= get_xgboost(x_train, x_test, y_train, y_test)

# %%
print('XGBOOST results')
print(best_params)
xgboost_results
# Out:
# XGBOOST results
# {'colsample_bytree': 1.0, 'learning_rate': 0.03, 'max_depth': 7, 'min_child_weight': 3, 'n_estimators': 350}
#          Mean Abs. Error  Root Mean Squared Error  Mean Percentage Error
# Results     68626.479903            107894.990848               0.098660

# %%
#plot feature importance
xgboost.plot_importance(xgb)
plt.rcParams['figure.figsize'] = [20, 20]
plt.show()

# %% [markdown]
# ## 6) In Conclusion

# %% [markdown]
# XGBoost with the previous sale rows, as well as the aggregations from the previous sale to the current sale exceeds the other models exceedingly.

# %% [markdown]
# **Business Takeaways**:
#
# Our best models fall with in the 10% range of error. This is promising. However, Zillow and other companies have claimed in recent years to have reached thee 5% marker with their models, therefore further work is still needed. What else is there left to do?
#
# 1) Gather **More** data
#
# 2) Gather **More** cities
#     * For example, unable currently to use the zip code-- a very valuable feature.
#
# 3) Understand better the houses with the larget error.
#
# 4) Use nearest neighbors to get the price of the closest neighbors (KNN and ALSO physical Neighbors)
#
# 5) PCA or other feature extraction tools (although with Gradient boosting methods, there isn't so much data to show that this will help).
#     * https://stats.stackexchange.com/questions/518532/does-it-make-sense-to-do-pca-before-a-tree-boosting-model
#
# 6) Model Ensembling
