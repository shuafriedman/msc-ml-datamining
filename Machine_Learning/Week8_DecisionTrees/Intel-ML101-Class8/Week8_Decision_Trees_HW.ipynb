# %% [markdown]
# # Decision Trees Exercises

# %% [markdown]
# ## Introduction
#
# We will be using the wine quality data set for these exercises. This data set contains various chemical properties of wine, such as acidity, sugar, pH, and alcohol. It also contains a quality metric (3-9, with highest being better) and a color (red or white). The name of the file is `Wine_Quality_Data.csv`.

# %% [markdown]
# ### Prerequisites
#
# Install pydotplus and seaborn in your own virtual environment
#
# !pip install pydotplus
#
# !pip install seaborn

# %%
import seaborn
import pydotplus

# %% [markdown]
# ## Question 1
#
# * Import the data and examine the features.
# * We will be using all of them to predict `color` (white or red), but the colors feature will need to be integer encoded.

# %%
import pandas as pd
import numpy as np

filepath = '/home/shua/Desktop/msc-ml-datamining/Machine_Learning/Week8_DecisionTrees/Intel-ML101-Class8/data/Wine_Quality_Data.csv'
data = pd.read_csv(filepath, sep=',')

# %%
data.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# 2      9.8        5   red
# 3      9.8        6   red
# 4      9.4        5   red

# %%
data.dtypes
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# color                    object
# dtype: object

# %% [markdown]
# Convert the color feature to an integer. This is a quick way to do it using Pandas.

# %%
data['color'] = data.color.replace('white',0).replace('red',1).astype('int')

# %% [markdown]
# ## Question 2
#
# * Use `StratifiedShuffleSplit` to split data into train and test sets that are stratified by wine quality. If possible, preserve the indices of the split for question 5 below.
# * Check the percent composition of each quality level for both the train and test data sets.

# %%
# All data columns except for color
feature_cols = [x for x in data.columns if x not in 'color']

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# Split the data into two parts with 1000 points in the test data
# This creates a generator
strat_shuff_split = StratifiedShuffleSplit(n_splits=1, test_size=1000, random_state=42)

# Get the index values from the generator
train_idx, test_idx = next(strat_shuff_split.split(data[feature_cols], data['color']))

# Create the data sets
X_train = data.loc[train_idx, feature_cols]
y_train = data.loc[train_idx, 'color']

X_test = data.loc[test_idx, feature_cols]
y_test = data.loc[test_idx, 'color']

# %% [markdown]
# Now check the percent composition of each quality level in the train and test data sets. The data set is mostly white wine, as can be seen below.

# %%
y_train.value_counts(normalize=True).sort_index()
# Out:
# 0    0.753866
# 1    0.246134
# Name: color, dtype: float64

# %%
y_test.value_counts(normalize=True).sort_index()
# Out:
# 0    0.754
# 1    0.246
# Name: color, dtype: float64

# %%
X_train.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 3627            8.9              0.21         0.34             7.1      0.037
# 1932            6.5              0.28         0.34             9.9      0.038
# 5055            6.0              0.39         0.13             1.2      0.042
# 2372            6.1              0.27         0.30            16.7      0.039
# 158             7.1              0.68         0.00             2.2      0.073
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 3627                 33.0                 150.0  0.99620  3.10       0.45
# 1932                 30.0                 133.0  0.99540  3.11       0.44
# 5055                 60.0                 172.0  0.99114  3.06       0.52
# 2372                 49.0                 172.0  0.99985  3.40       0.45
# 158                  12.0                  22.0  0.99690  3.48       0.50
#
#       alcohol  quality
# 3627      9.7        6
# 1932      9.8        5
# 5055     10.6        5
# 2372      9.4        5
# 158       9.3        5

# %% [markdown]
# ## Question 3
#
# * Fit a decision tree classifier with no set limits on maximum depth, features, or leaves.
# * Determine how many nodes are present and what the depth of this (very large) tree is.
# * Using this tree, measure the prediction error in the train and test data sets. What do you think is going on here based on the differences in prediction error?

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=42)
dt = dt.fit(X_train, y_train)

# %% [markdown]
# The number of nodes and the maximum actual depth.

# %%
dt.tree_.node_count, dt.tree_.max_depth
# Out:
# (171, 22)

# %% [markdown]
# #Train a shallow DT

# %%
dt_shallow = DecisionTreeClassifier(max_depth=5,random_state=42)
dt_shallow = dt_shallow.fit(X_train, y_train)

# %%
dt_shallow.tree_.node_count, dt_shallow.tree_.max_depth
# Out:
# (43, 5)

# %% [markdown]
# A function to return error metrics.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def measure_error(y_true, y_pred, label):
    return pd.Series({'accuracy':accuracy_score(y_true, y_pred),
                      'precision': precision_score(y_true, y_pred),
                      'recall': recall_score(y_true, y_pred),
                      'f1': f1_score(y_true, y_pred)},
                      name=label)

# %% [markdown]
# The decision tree predicts a little better on the training data than the test data, which is consistent with (mild)  overfitting. Also notice the perfect recall score for the training data. In many instances, this prediction difference is even greater than that seen here.

# %%
# The error on the training and test data sets
y_train_pred = dt.predict(X_train)
y_test_pred = dt.predict(X_test)

train_test_full_error = pd.concat([measure_error(y_train, y_train_pred, 'train'),
                              measure_error(y_test, y_test_pred, 'test')],
                              axis=1)

train_test_full_error
# Out:
#               train      test
# accuracy   0.999818  0.984000
# precision  0.999261  0.963710
# recall     1.000000  0.971545
# f1         0.999631  0.967611

# %%
# The error on the training and test data sets for the shallow DT
y_train_pred = dt_shallow.predict(X_train)
y_test_pred = dt_shallow.predict(X_test)

train_test_full_error = pd.concat([measure_error(y_train, y_train_pred, 'train'),
                              measure_error(y_test, y_test_pred, 'test')],
                              axis=1)

train_test_full_error
# Out:
#               train      test
# accuracy   0.989813  0.984000
# precision  0.991660  0.979167
# recall     0.966741  0.955285
# f1         0.979042  0.967078

# %% [markdown]
# ## Question 4
#
# * Using grid search with cross validation, find a decision tree that performs well on the test data set. Use a different variable name for this decision tree model than in question 3 so that both can be used in question 6.
# * Determine the number of nodes and the depth of this tree.
# * Measure the errors on the training and test sets as before and compare them to those from the tree in question 3.

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'max_depth':range(1, dt.tree_.max_depth+1, 2),
              'max_features': range(1, len(dt.feature_importances_)+1)}

GR = GridSearchCV(DecisionTreeClassifier(random_state=42),
                  param_grid=param_grid,
                  scoring='accuracy',
                  n_jobs=-1)

GR = GR.fit(X_train, y_train)

# %% [markdown]
# The number of nodes and the maximum depth of the tree.

# %%
GR.best_estimator_.tree_.node_count, GR.best_estimator_.tree_.max_depth
# Out:
# (99, 7)

# %% [markdown]
# These test errors are a little better than the previous ones. So it would seem the previous example overfit the data, but only slightly so.

# %%
y_train_pred_gr = GR.predict(X_train)
y_test_pred_gr = GR.predict(X_test)

train_test_gr_error = pd.concat([measure_error(y_train, y_train_pred_gr, 'train'),
                                 measure_error(y_test, y_test_pred_gr, 'test')],
                                axis=1)

# %%
train_test_gr_error
# Out:
#               train      test
# accuracy   0.995816  0.989000
# precision  0.998501  0.983539
# recall     0.984479  0.971545
# f1         0.991440  0.977505

# %% [markdown]
# ## Question 5
#
# * Re-split the data into `X` and `y` parts, this time with `residual_sugar` being the predicted (`y`) data. *Note:* if the indices were preserved from the `StratifiedShuffleSplit` output in question 2, they can be used again to split the data.
# * Using grid search with cross validation, find a decision tree **regression** model that performs well on the test data set.
# * Measure the errors on the training and test sets using mean squared error.
# * Make a plot of actual *vs* predicted residual sugar.

# %%
feature_cols = [x for x in data.columns if x != 'residual_sugar']

# Create the data sets
X_train = data.loc[train_idx, feature_cols]
y_train = data.loc[train_idx, 'residual_sugar']

X_test = data.loc[test_idx, feature_cols]
y_test = data.loc[test_idx, 'residual_sugar']

# %%
from sklearn.tree import DecisionTreeRegressor

dr = DecisionTreeRegressor().fit(X_train, y_train)

param_grid = {'max_depth':range(1, dr.tree_.max_depth+1, 2),
              'max_features': range(1, len(dr.feature_importances_)+1)}

GR_sugar = GridSearchCV(DecisionTreeRegressor(random_state=42),
                     param_grid=param_grid,
                     scoring='neg_mean_squared_error',
                      n_jobs=-1)

GR_sugar = GR_sugar.fit(X_train, y_train)

# %% [markdown]
# The number of nodes and the maximum depth of the tree. This tree has lots of nodes, which is not so surprising given the continuous data.

# %%
GR_sugar.best_estimator_.tree_.node_count, GR_sugar.best_estimator_.tree_.max_depth
# Out:
# (7953, 25)

# %% [markdown]
# The error on train and test data sets. Since this is continuous, we will use mean squared error.

# %%
from sklearn.metrics import mean_squared_error

y_train_pred_gr_sugar = GR_sugar.predict(X_train)
y_test_pred_gr_sugar  = GR_sugar.predict(X_test)

train_test_gr_sugar_error = pd.Series({'train': mean_squared_error(y_train, y_train_pred_gr_sugar),
                                         'test':  mean_squared_error(y_test, y_test_pred_gr_sugar)},
                                          name='MSE').to_frame().T

train_test_gr_sugar_error
# Out:
#        train      test
# MSE  0.00055  2.659874

# %% [markdown]
# A plot of actual vs predicted residual sugar.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context('notebook')
sns.set_style('white')
sns.set_palette('dark')

# %matplotlib inline

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.axes()

ph_test_predict = pd.DataFrame({'test':y_test.values,
                                'predict': y_test_pred_gr_sugar}).set_index('test').sort_index()

ph_test_predict.plot(marker='o', ls='', ax=ax)
ax.set(xlabel='Test', ylabel='Predict', xlim=(0,35), ylim=(0,35));

# %% [markdown]
# ## Question 6 *(Optional)*
#
# This question is optional as it requires an additional command line program (GraphViz) and Python library (PyDotPlus). GraphViz can be installed with a package manager on Linux and Mac. For PyDotPlus, either `pip` or `conda` (`conda install -c conda-forge pydotplus`) can be used to install the library.
#
# Once these programs are installed:
#
# * Create a visualization of the decision tree from question 3, where wine color was predicted and the number of features and/or splits are not limited.
# * Create a visualization of the decision tree from question 4, where wine color was predicted but a grid search was used to find the optimal depth and number of features.
#
# The decision tree from question 5 will likely have too many nodes to visualize.

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /home/shua/miniconda3/envs/lev_ml/lib/python3.10/site-packages (0.20.1)

# %%
from io import StringIO
from IPython.display import Image, display

from sklearn.tree import export_graphviz

try:
    import pydotplus
    pydotplus_installed = True
    
except:
    print('PyDotPlus must be installed to execute the remainder of the cells associated with this question.')
    print('Please see the instructions for this question for details.')
    pydotplus_installed = False

# %% [markdown]
# The tree from question 3.

# %%
if pydotplus_installed:
    
    # Create an output destination for the file
    dot_data = StringIO()

    export_graphviz(dt, out_file=dot_data, filled=True)
    graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
    print(graph)
    # View the tree image
    filename = 'wine_tree.png'
    graph.write_png(filename)
    img = Image(filename=filename)
    display(img)
    
else:
    print('This cell not executed because PyDotPlus could not be loaded.')
# Out:
# <pydotplus.graphviz.Dot object at 0x7f923d7b4b50>

# %% [markdown]
# The tree fit with cross validation from question 4. This tree is much shallower than the previous one.

# %%
if pydotplus_installed:
    
    # Create an output destination for the file
    dot_data = StringIO()

    export_graphviz(GR.best_estimator_, out_file=dot_data, filled=True)
    graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

    # View the tree image
    filename = 'wine_tree_prune.png'
    graph.write_png(filename)
    img = Image(filename=filename) 
    display(img)
    
else:
    print('This cell not executed because PyDotPlus could not be loaded.')

# %%
if pydotplus_installed:
    
    # Create an output destination for the file
    dot_data = StringIO()

    export_graphviz(dt_shallow, out_file=dot_data, filled=True)
    graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
    print(graph)
    # View the tree image
    filename = 'wine_tree.png'
    graph.write_png(filename)
    img = Image(filename=filename)
    display(img)
    
else:
    print('This cell not executed because PyDotPlus could not be loaded.')
# Out:
# <pydotplus.graphviz.Dot object at 0x7f91f53377c0>

# %% [markdown]
# ## Question 7
# * Import the iris data and examine the features.
# * We will be using all of them to predict species, but the species feature will need to be integer encoded.

# %%
data = pd.read_csv('/home/shua/Desktop/msc-ml-datamining/Machine_Learning/Week8_DecisionTrees/Intel-ML101-Class8/data/Iris_Data.csv')

# %% [markdown]
# Convert the species feature to an integer. This is a quick way to do it using Pandas.

# %%
#convert the species column to numeric
data['species'] = data['species'].map({'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2})

# %% [markdown]
# ## Question 8
#
# * Use `StratifiedShuffleSplit` to split data into train and test sets that are stratified by species. If possible, preserve the indices of the split for question 11 below.
# * Check the percent composition of each species level for both the train and test data sets.

# %%
# All data columns except for species
feature_cols = [x for x in data.columns if x != 'species']
# Create the data sets
strat_shuff_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=1)

train_idx, test_idx = next(strat_shuff_split.split(data, data['species']))

X_train = data.loc[train_idx, feature_cols]
y_train = data.loc[train_idx, 'species']

X_test = data.loc[test_idx, feature_cols]
y_test = data.loc[test_idx, 'species']

# %% [markdown]
# Now check the percent composition of each species in the train and test iris_data sets. The iris_data set is equally distributed, as can be seen below.

# %%
#check percent composition of each class in the training and test sets
print('Training set composition')
print(y_train.value_counts(normalize=True))
print('Test set composition')
print(y_test.value_counts(normalize=True))
# Out:
# Training set composition
# 0    0.333333
# 2    0.333333
# 1    0.333333
# Name: species, dtype: float64
# Test set composition
# 2    0.333333
# 0    0.333333
# 1    0.333333
# Name: species, dtype: float64

# %% [markdown]
# ## Question 9
#
# * Fit a decision tree classifier with no set limits on maximum depth, features, or leaves.
# * Determine how many nodes are present and what the depth of this (very large) tree is.
# * Using this tree, measure the prediction error in the train and test iris_data sets. What do you think is going on here based on the differences in prediction error?

# %%
#fit decision tree with no limits on max depth, features, or leaves
dt = DecisionTreeClassifier(random_state=42, max_depth=None, max_features=None, max_leaf_nodes=None)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# The number of nodes and the maximum actual depth.

# %%
print('The number of nodes in the tree is {}'.format(dt.tree_.node_count))
print('The depth of the tree is {}'.format(dt.tree_.max_depth))
# Out:
# The number of nodes in the tree is 17
# The depth of the tree is 6

# %% [markdown]
# A function to return error metrics.
# #### HINT: This is not a binary classification problem, IRIS data set has 3 classes in target column. Check on score functions

# %%
#a function to return error metrics
def get_error_metrics(y_true, y_pred):
    return pd.Series({'Accuracy': accuracy_score(y_true, y_pred),
                      'Precision': precision_score(y_true, y_pred, average='weighted'),
                      'Recall': recall_score(y_true, y_pred, average='weighted'),
                      'F1': f1_score(y_true, y_pred, average='weighted')})

y_train_pred = dt.predict(X_train)
y_test_pred = dt.predict(X_test)
#show the metrics
train_test_error = pd.DataFrame({'train': get_error_metrics(y_train, y_train_pred), 'test': get_error_metrics(y_test, y_test_pred)})
train_test_error
# Out:
#            train      test
# Accuracy     1.0  0.966667
# Precision    1.0  0.969697
# Recall       1.0  0.966667
# F1           1.0  0.966583

# %% [markdown]
# The decision tree predicts a little better on the training iris_data than the test iris_data, which is consistent with (mild)  overfitting. Also notice the perfect recall score for the training iris_data. In many instances, this prediction difference is even greater than that seen here.

# %% [markdown]
# ## Question 10
#
# * Using grid search with cross validation, find a decision tree that performs well on the test iris_data set. Use a different variable name for this decision tree model than in question 9 so that both can be used in question 12.
# * Determine the number of nodes and the depth of this tree.
# * Measure the errors on the training and test sets as before and compare them to those from the tree in question 9.

# %%
#use grid search to find the best max depth and max features
param_grid = {'max_depth': range(1, dt.tree_.max_depth+1), 'max_features': range(1, len(X_train.columns)+1)}
GR = GridSearchCV(DecisionTreeClassifier(random_state=1), param_grid, cv=3, scoring='accuracy')
GR.fit(X_train, y_train)
#measure the errors on training and test
y_train_pred_gr = GR.predict(X_train)
y_test_pred_gr = GR.predict(X_test)
#show the metrics
train_test_error = pd.DataFrame({'train': get_error_metrics(y_train, y_train_pred_gr), 'test': get_error_metrics(y_test, y_test_pred_gr)})
train_test_error
# Out:
#               train      test
# Accuracy   0.991667  0.966667
# Precision  0.991870  0.969697
# Recall     0.991667  0.966667
# F1         0.991665  0.966583

# %%
GR.best_params_
# Out:
# {'max_depth': 5, 'max_features': 2}

# %% [markdown]
# The number of nodes and the maximum depth of the tree.

# %%
#the number of nodes and the max depth of the tree
print('The number of nodes in the tree is {}'.format(GR.best_estimator_.tree_.node_count))
print('The depth of the tree is {}'.format(GR.best_estimator_.tree_.max_depth))
# Out:
# The number of nodes in the tree is 15
# The depth of the tree is 5

# %% [markdown]
# These test errors are a little better than the previous ones. So it would seem the previous example overfit the iris_data, but only slightly so.
